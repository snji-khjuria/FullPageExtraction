# %%
import os
def getAllDirectoriesInLocation(loc):
    listOfSubDir = [loc+"/"+f for f in os.listdir(loc)]
    return listOfSubDir

def removeAllFilessNamed(directory, fileName):
    subdirs = getAllDirectoriesInLocation(directory)
    for d in subdirs:
        fname = d+"/"+fileName
        os.remove(fname)
#         deletefile(fname)
        print("deleted " + fname)
    print("Everything is deleted")
    
removeAllFilessNamed("testingData", "output.html")
# Out:
# deleted testingData/page1/output.html
# deleted testingData/page94/output.html
# deleted testingData/page56/output.html
# deleted testingData/page6/output.html
# deleted testingData/page18/output.html
# deleted testingData/page76/output.html
# deleted testingData/page81/output.html
# deleted testingData/page26/output.html
# deleted testingData/page86/output.html
# deleted testingData/page32/output.html
# deleted testingData/page7/output.html
# deleted testingData/page49/output.html
# deleted testingData/page25/output.html
# deleted testingData/page52/output.html
# deleted testingData/page38/output.html
# deleted testingData/page80/output.html
# deleted testingData/page15/output.html
# deleted testingData/page93/output.html
# deleted testingData/page22/output.html
# deleted testingData/page5/output.html
# deleted testingData/page78/output.html
# deleted testingData/page20/output.html
# deleted testingData/page98/output.html
# deleted testingData/page92/output.html
# deleted testingData/page30/output.html
# deleted testingData/page37/output.html
# deleted testingData/page97/output.html
# deleted testingData/page96/output.html
# deleted testingData/page40/output.html
# deleted testingData/page63/output.html
# deleted testingData/page55/output.html
# deleted testingData/page73/output.html
# deleted testingData/page89/output.html
# deleted testingData/page53/output.html
# deleted testingData/page21/output.html
# deleted testingData/page79/output.html
# deleted testingData/page70/output.html
# deleted testingData/page43/output.html
# deleted testingData/page35/output.html
# deleted testingData/page66/output.html
# deleted testingData/page72/output.html
# deleted testingData/page64/output.html
# deleted testingData/page41/output.html
# deleted testingData/page88/output.html
# deleted testingData/page45/output.html
# deleted testingData/page50/output.html
# deleted testingData/page83/output.html
# deleted testingData/page16/output.html
# deleted testingData/page14/output.html
# deleted testingData/page68/output.html
# deleted testingData/page74/output.html
# deleted testingData/page85/output.html
# deleted testingData/page8/output.html
# deleted testingData/page3/output.html
# deleted testingData/page59/output.html
# deleted testingData/page60/output.html
# deleted testingData/page90/output.html
# deleted testingData/page99/output.html
# deleted testingData/page9/output.html
# deleted testingData/page62/output.html
# deleted testingData/page23/output.html
# deleted testingData/page28/output.html
# deleted testingData/page95/output.html
# deleted testingData/page58/output.html
# deleted testingData/page47/output.html
# deleted testingData/page10/output.html
# deleted testingData/page34/output.html
# deleted testingData/page51/output.html
# deleted testingData/page27/output.html
# deleted testingData/page24/output.html
# deleted testingData/page33/output.html
# deleted testingData/page91/output.html
# deleted testingData/page29/output.html
# deleted testingData/page44/output.html
# deleted testingData/page31/output.html
# deleted testingData/page54/output.html
# deleted testingData/page17/output.html
# deleted testingData/page39/output.html
# deleted testingData/page77/output.html
# deleted testingData/page71/output.html
# deleted testingData/page2/output.html
# deleted testingData/page61/output.html
# deleted testingData/page67/output.html
# deleted testingData/page36/output.html
# deleted testingData/page46/output.html
# deleted testingData/page11/output.html
# deleted testingData/page75/output.html
# deleted testingData/page100/output.html
# deleted testingData/page48/output.html
# deleted testingData/page69/output.html
# deleted testingData/page4/output.html
# deleted testingData/page84/output.html
# deleted testingData/page82/output.html
# deleted testingData/page57/output.html
# deleted testingData/page13/output.html
# deleted testingData/page12/output.html
# deleted testingData/page42/output.html
# deleted testingData/page65/output.html
# deleted testingData/page19/output.html
# deleted testingData/page87/output.html
# Everything is deleted
