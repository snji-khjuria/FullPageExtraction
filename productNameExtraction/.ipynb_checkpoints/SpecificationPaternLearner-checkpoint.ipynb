# %%
import os
import re
from os import listdir
from os.path import isfile, join
#corpus directory for flipkart
# productNameData/flipkart/corpus
print("Enter the corpus directory out of which we'll learn patterns: ")
# corpusDirectory = raw_input()
corpusDirectory = "featureSpecificationData/snapdeal/corpus"
print("Corpus directory is " + corpusDirectory)
directories = getAllDirectoriesInLocation(corpusDirectory)
(trainDirs, testDirs) = trainTestSplit(directories)
print("Train Files are " + str(trainDirs))
print("Test files are " + str(testDirs))
# Out:
# Enter the corpus directory out of which we'll learn patterns:
# Corpus directory is featureSpecificationData/snapdeal/corpus
# Train Files are ['featureSpecificationData/snapdeal/corpus/page1', 'featureSpecificationData/snapdeal/corpus/page6', 'featureSpecificationData/snapdeal/corpus/page7', 'featureSpecificationData/snapdeal/corpus/page5', 'featureSpecificationData/snapdeal/corpus/page8', 'featureSpecificationData/snapdeal/corpus/page3']
# Test files are ['featureSpecificationData/snapdeal/corpus/page9', 'featureSpecificationData/snapdeal/corpus/page10', 'featureSpecificationData/snapdeal/corpus/page2', 'featureSpecificationData/snapdeal/corpus/page4']

# %%
#do train/test split
def trainTestSplit(files):
    sixtyPercent = int(len(files)*(0.6))
    if sixtyPercent<4:
        print("We won't be able to report accuracy of patterns")
        return (files, [])
    else:
        return (files[:sixtyPercent], files[sixtyPercent:])

def getAllDirectoriesInLocation(loc):
    listOfSubDir = [loc+"/"+f for f in os.listdir(loc)]
    return listOfSubDir


def readAllSeedsAsSet(fileLocation):
    with open(fileLocation) as f:
        content = f.readlines()
    content = [removeMultipleWhiteSpaces(x.strip()) for x in content]
    return set(content)

def removeMultipleWhiteSpaces(s):
    return ' '.join(s.split())


def getSpecificationsSeed(fileLocation):
    with open(fileLocation) as f:
        content = f.readlines()
    content = [removeMultipleWhiteSpaces(x.strip()) for x in content] 
#     print("content is " + str(content))
    return content[1:len(content)-1]


def getPageLocationAndSeed(d):
    output = []
    for pageDir in d:
        pageLocation = pageDir + "/page.html"
        seedLocation = pageDir + "/seed"
        seed = getSpecificationsSeed(seedLocation)
        output.append((pageLocation, seed))
    return output

# %%
#read the page from pageLocation
def readPage(pageLocation):
    htmlPageContent = ""
    with open(pageLocation, 'r') as myfile:
        htmlPageContent = myfile.read().strip()
    return htmlPageContent

def removeTerminatedAnd(s):
    return re.sub("&amp;", "&", s)



#document processing logic at this stage is about removing multiple whitespaces into single one 
def preprocessDocument(document):
    return removeTerminatedAnd(' '.join(document.split()))




def getLeftAndRightContexts(pageContent, seed):
    b = getEachSeedLocationsInPage(pageContent, seed)
    output = []
    totalLength = len(pageContent)
    leftContexts = []
    rightContexts = []
    for (s, e) in b:
        leftContext = pageContent[max(0, s-100):s]
        leftContext = leftContext[::-1]
        rightContext = pageContent[e:min(totalLength, e+100)]
        leftContexts.append(leftContext)
        rightContexts.append(rightContext)
    return (leftContexts, rightContexts)
    
    
#find all start, end pairs of particular key
def getAllStartEndPairs(document, key):
    keyLength = len(key)
    return [(i, i+keyLength) for i in range(len(document)) if document.startswith(key, i)]
 
    
#find seeds for one particular seed(at this stage call only getAllStartEndPairs())
def getEachSeedLocationsInPage(htmlPageContent, seed):
    return getAllStartEndPairs(htmlPageContent, seed)

def printContextInformation(contexts, pageAndSeed, rev=False):
    for index in range(0, len(pageAndSeed)):
        print("\n\n\n\n")
        (pageLocation, seed) = pageAndSeed[index]
        pageContent = preprocessDocument(readPage(pageLocation))
        contextPerPage = contexts[index]
        print("For seed " + str(seed))
        print("Context is following: " + pageLocation)# + " number " + str(contextPerPage))
        for item in contextPerPage:
            if rev==True:
                item = item[::-1]
            print(item)
            print("---------------------")

def getCommonPrefix(s1, s2):
    l = [s1, s2]
    return os.path.commonprefix(l)



def insertCommonPrefix(results, commonPrefix):
    if commonPrefix in results or len(commonPrefix)<=0:
        return results
    r = list(results)
    for item in r:
        if len(item)<len(commonPrefix) and commonPrefix.startswith(item):
            results.remove(item)
    r=list(results)
    for item in r:
        if len(item)>len(commonPrefix) and item.startswith(commonPrefix):
            return results
    results.add(commonPrefix)
    return results

def doPrefixIntersection(list1, list2):
    results = set()
    for item1 in list1:
        commonPrefix = ""
        for item2 in list2:
            c = getCommonPrefix(item1, item2)
            if len(c)>len(commonPrefix):
                commonPrefix = c
        results = insertCommonPrefix(results, commonPrefix)
    return results


def doIntersection(patterns):
    if len(patterns)<=0:
        return patterns
    result = patterns[0]
    for index in range(1, len(patterns)):
        result = doPrefixIntersection(result, patterns[index])
    return result


def getLeftPatterns(leftContexts):
    lp = doIntersection(leftContexts)
    results = []
    for item in lp:
        results.append(item[::-1]) 
    return results


def getRightPatterns(rightContexts):
    return list(doIntersection(rightContexts))


def allPossiblePairs(leftPatterns, rightPatterns):
    patterns = []
    for lp in leftPatterns:
        for rp in rightPatterns:
            patterns.append((lp, rp))
    return patterns

#Pattern is (l, r) and match them to htmlPageContent
def findEntitySetwrtPattern(htmlPageContent, (l, r)):
    #for each start location of pattern find its end
    #for each end page find the pattern right
    #extract everything till that point
    #after extraction move one point above that pattern string
    results = []
    for m in re.finditer(re.escape(l), htmlPageContent):
        start = m.start()
        end = m.end()
        rightPage = htmlPageContent[end:]
        rightLoc  = rightPage.find(r)
        if rightLoc==-1:
            break
        element = rightPage[:rightLoc]
        if len(element)>1 and len(element)<500:
            results.append(element)
    return set(results)


def extractSet(patterns, htmlPageContent):
    output = []
    for pattern in patterns:
        output.extend(findEntitySetwrtPattern(htmlPageContent, pattern))
    return set(output)

def filterPatterns(pageLocationAndSeeds, patterns, applyClass=False):
    seedsSet = set()
    for (pageLoc, seed) in pageLocationAndSeeds:
        for s in seed:
            seedsSet.add(s)
    seeds = list(seedsSet)
    patternSuccess = []
    for index in range(0, len(patterns)):
        patternSuccess.append(0)
    for index in range(0, len(patterns)):
        for (pageLocation, seed) in pageLocationAndSeeds:
            pageContent = preprocessDocument(readPage(pageLocation))
            if applyClass == True:
                pageContent = doProcessingWithoutClass(pageContent)
            resultsFound = extractSet([patterns[index]], pageContent)
            flag = True
            for s in seed:
                if not s in resultsFound:
                    flag=False
            if flag==True:
                patternSuccess[index]+=1
                
    output = []
    for index in range(0, len(patterns)):
        if patternSuccess[index]>0:
            output.append(patterns[index])
    return output


#remove elements which were actually tag
def isTag(s):
    if s.find("<")!=-1 and s.find(">")!=-1:
        return True
    return False


#preprocess results before writing it to file
def preprocessResults(output):
    result = []
    for o in output:
        if isTag(o):
            continue
        result.append(o)
    return result



def doProcessingWithoutClass(s):
    i = "class[\s]*=[\s]*"
    o       = "class="
    s = re.sub(i, o, s)
    i = "([^class])=\"[^\"]*\""
    o = "\\1=\"\""
    return re.sub(i, o, s)

def getContextsForAllSeeds(pageContent, seed):
    lout = []
    rout = []
    for s in seed:
        (lcPerS, rcPerS) = getLeftAndRightContexts(pageContent, s)
        lout.append(lcPerS)
        rout.append(rcPerS)
    return (lout, rout)

# %%
def getAllPatternsByPlainStringMatch(corpusLocation):
    directories             = getAllDirectoriesInLocation(corpusLocation)
    (trainDirs, testDirs)   = trainTestSplit(directories)
    pageLocationsAndSeed    = getPageLocationAndSeed(trainDirs)
    testPageLocationAndSeed = getPageLocationAndSeed(testDirs)
    leftContexts  = []
    rightContexts = []
    for (pageLocation, seed) in pageLocationsAndSeed:
#         print("pageLocation is " + pageLocation)
#         print("seed is ")
#         print(seed)
        pageContent = preprocessDocument(readPage(pageLocation))
        (leftContextsPerPage, rightContextsPerPage) = getContextsForAllSeeds(pageContent, seed)
        if [] in leftContextsPerPage:
            print(pageLocation + " has some empty seed")
#             error
#         (leftContextsPerPage, rightContextsPerPage) = getLeftAndRightContexts(pageContent, seed)
        leftContexts.extend(leftContextsPerPage)
        rightContexts.extend(rightContextsPerPage)
#     printContextInformation(leftContexts, pageLocationsAndSeed, True)
#     printContextInformation(rightContexts, pageLocationsAndSeed)
    print("Total left contexts ")
    print(leftContexts)
    leftPatterns = getLeftPatterns(leftContexts)
    rightPatterns = getRightPatterns(rightContexts)
#     print(leftPatterns)
#     print(rightPatterns)
    
#     print("Left patterns are " + str(leftPatterns))
#     print("Right patterns are " + str(rightPatterns))
    patterns = allPossiblePairs(leftPatterns, rightPatterns)
#     print("All possible patterns: ")
#     print(patterns)
    patterns = filterPatterns(pageLocationsAndSeed, patterns)
    #TODO if number of patterns are empty go for empty class thing
#     print("Final Patterns ")
#     print(patterns)
    recall = 0
    extraResults = 0
    for (pageLocation, seed) in testPageLocationAndSeed:
        pageContent = preprocessDocument(readPage(pageLocation))
        resultsPerPage = preprocessResults(list(extractSet(patterns, pageContent)))
#         resultsPerPage = list(set(resultsPerPage))
        flag=True
        for s in seed:
            if not s in resultsPerPage:
                flag=False
        if flag==True:
            recall+=1
#         if seed in resultsPerPage:
#             recall += 1
        extraElements = len(resultsPerPage) - len(seed)
        if extraElements>1:
            seedsLocation = os.path.dirname(pageLocation) + "/seed"
            allSeeds = readAllSeedsAsSet(seedsLocation)
            totalCount = len(resultsPerPage)
            allSeedsCount = len(list(allSeeds.intersection(set(resultsPerPage))))
            extracount = totalCount - allSeedsCount
            extraResults += extracount
#         print("Results per page " + str(resultsPerPage))
    seedsMissed = len(testPageLocationAndSeed)-recall
#     print("Seeds missed: " + str(seedsMissed))
#     print("Extra junk: "+ str(extraResults))
    return (patterns, seedsMissed, extraResults, len(testDirs))
    
getAllPatternsByPlainStringMatch(corpusDirectory)
# Out:
# Total left contexts
# [['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<taoB>"tnetnoc-h"=ssalc naps< >naps/<>"elcric', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"raE nI:epyT"=eltit "gniddap-teser 8-sx-l', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<raE nI:epyT>"tnetnoc-h"=ssalc naps< >naps/<>', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"deriW:sseleriW ro deriW"=eltit "gniddap-', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<deriW:sseleriW ro deriW>"tnetnoc-h"=ssalc na', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"ciM htiW:ciM tuohtiW ro htiW"=eltit "gni', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<ciM htiW:ciM tuohtiW ro htiW>"tnetnoc-h"=ssa', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"5.3:)mm ni( retemaiD kcaJ"=eltit "gnidda', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<raeY 1:doireP ytnarraW>"tnetnoc-h"=ssalc nap', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"emoH:egasU"=eltit "gniddap-teser 8-sx-lo', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<emoH:egasU>"tnetnoc-h"=ssalc naps< >naps/<>"', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>")AGXW( 867x6631:noituloseR"=eltit "gnidd', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<)AGXW( 867x6631:noituloseR>"tnetnoc-h"=ssalc', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"2:)zHG ni( deepS kcolC esaB"=eltit "gnid', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<2:)zHG ni( deepS kcolC esaB>"tnetnoc-h"=ssal', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"oN:draobyeK tilkcaB"=eltit "gniddap-tese', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], [' "=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<mm 0021 :eziS naF/peewS>"tnetnoc-h"=ssalc n', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>" sedalB 3 :sedalB fo .oN "=eltit "gnidda', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], [' "=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<sedalB 3 :sedalB fo .oN>"tnetnoc-h"=ssalc n', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>" sttaW 56 :rewoP "=eltit "gniddap-teser ', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], [' "=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<sttaW 56 :rewoP>"tnetnoc-h"=ssalc naps< >na', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>" 512 :yrevileD riA "=eltit "gniddap-tese', '>"tnetnoc-h"= ...
# Called with
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<taoB>"tnetnoc-h"=ssalc naps< >naps/<>"elcric', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"raE nI:epyT"=eltit "gniddap-teser 8-sx-l', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# ---------
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<raE nI:epyT>"tnetnoc-h"=ssalc naps< >naps/<>', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"deriW:sseleriW ro deriW"=eltit "gniddap-', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<'])
# Called with
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<taoB>"tnetnoc-h"=ssalc naps< >naps/<>"elcric', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"raE nI:epyT"=eltit "gniddap-teser 8-sx-l', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# ---------
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<raE nI:epyT>"tnetnoc-h"=ssalc naps< >naps/<>', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"deriW:sseleriW ro deriW"=eltit "gniddap-', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"', '"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<'])
# Called with
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<taoB>"tnetnoc-h"=ssalc naps< >naps/<>"elcric', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"raE nI:epyT"=eltit "gniddap-teser 8-sx-l', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# ---------
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<raE nI:epyT>"tnetnoc-h"=ssalc naps< >naps/<>', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"deriW:sseleriW ro deriW"=eltit "gniddap-', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"', '"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"', '"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<deriW:sseleriW ro deriW>"tnetnoc-h"=ssalc na', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"ciM htiW:ciM tuohtiW ro htiW"=eltit "gni', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"', '"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<deriW:sseleriW ro deriW>"tnetnoc-h"=ssalc na', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"ciM htiW:ciM tuohtiW ro htiW"=eltit "gni', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"', '"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"', '"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<deriW:sseleriW ro deriW>"tnetnoc-h"=ssalc na', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"ciM htiW:ciM tuohtiW ro htiW"=eltit "gni', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"', '"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"', '"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<ciM htiW:ciM tuohtiW ro htiW>"tnetnoc-h"=ssa', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"5.3:)mm ni( retemaiD kcaJ"=eltit "gnidda', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"', '"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<ciM htiW:ciM tuohtiW ro htiW>"tnetnoc-h"=ssa', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"5.3:)mm ni( retemaiD kcaJ"=eltit "gnidda', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"', '"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"', '"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<ciM htiW:ciM tuohtiW ro htiW>"tnetnoc-h"=ssa', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"5.3:)mm ni( retemaiD kcaJ"=eltit "gnidda', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"', '"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"', '"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"', '"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"', '"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<raeY 1:doireP ytnarraW>"tnetnoc-h"=ssalc nap', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"emoH:egasU"=eltit "gniddap-teser 8-sx-lo', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<emoH:egasU>"tnetnoc-h"=ssalc naps< >naps/<>"', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>")AGXW( 867x6631:noituloseR"=eltit "gnidd', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<)AGXW( 867x6631:noituloseR>"tnetnoc-h"=ssalc', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"2:)zHG ni( deepS kcolC esaB"=eltit "gnid', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<2:)zHG ni( deepS kcolC esaB>"tnetnoc-h"=ssal', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"oN:draobyeK tilkcaB"=eltit "gniddap-tese', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# [' "=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<mm 0021 :eziS naF/peewS>"tnetnoc-h"=ssalc n', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>" sedalB 3 :sedalB fo .oN "=eltit "gnidda', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# [' "=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<sedalB 3 :sedalB fo .oN>"tnetnoc-h"=ssalc n', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>" sttaW 56 :rewoP "=eltit "gniddap-teser ', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# [' "=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<sttaW 56 :rewoP>"tnetnoc-h"=ssalc naps< >na', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>" 512 :yrevileD riA "=eltit "gniddap-tese', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# [' "=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<512 :yrevileD riA>"tnetnoc-h"=ssalc naps< >', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>" MPR 083 :deepS "=eltit "gniddap-teser 8', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<raeY 1:doireP ytnarraW>"tnetnoc-h"=ssalc nap', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"emoH:egasU"=eltit "gniddap-teser 8-sx-lo', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<emoH:egasU>"tnetnoc-h"=ssalc naps< >naps/<>"', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>")AGXW( 867x6631:noituloseR"=eltit "gnidd', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<)AGXW( 867x6631:noituloseR>"tnetnoc-h"=ssalc', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"8.1:)zHG ni( deepS kcolC esaB"=eltit "gn', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<8.1:)zHG ni( deepS kcolC esaB>"tnetnoc-h"=ss', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"oN:draobyeK tilkcaB"=eltit "gniddap-tese', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<sdiK RS>"tnetnoc-h"=ssalc naps< >naps/<>"elc', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"roloC itluM:roloC"=eltit "gniddap-teser ', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<roloC itluM:roloC>"tnetnoc-h"=ssalc naps< >n', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"kcen dnuoR:epyT"=eltit "gniddap-teser 8-', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<kcen dnuoR:epyT>"tnetnoc-h"=ssalc naps< >nap', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"nottoC %001:cirbaF"=eltit "gniddap-teser', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<nottoC %001:cirbaF>"tnetnoc-h"=ssalc naps< >', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"seveelS flaH:seveelS"=eltit "gniddap-tes', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<tsurT .rD>"tnetnoc-h"=ssalc naps< >naps/<>"e', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"citamotua retpadA htiw gniklaT ecnagelE ', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<citamotua retpadA htiw gniklaT ecnagelE )ASU', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"seY:yalpsiD DCL"=eltit "gniddap-teser 8-', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<seY:yalpsiD DCL>"tnetnoc-h"=ssalc naps< >nap', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"htoB:ylppuS rewoP"=eltit "gniddap-teser ', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<htoB:ylppuS rewoP>"tnetnoc-h"=ssalc naps< >n', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"raeY 1:ytnarraW"=eltit "gniddap-teser 8-', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# Called with
# set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# ---------
# ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i']
# Returning common prefix for set(['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'])
# called with [['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<taoB>"tnetnoc-h"=ssalc naps< >naps/<>"elcric', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"raE nI:epyT"=eltit "gniddap-teser 8-sx-l', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<raE nI:epyT>"tnetnoc-h"=ssalc naps< >naps/<>', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"deriW:sseleriW ro deriW"=eltit "gniddap-', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<deriW:sseleriW ro deriW>"tnetnoc-h"=ssalc na', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"ciM htiW:ciM tuohtiW ro htiW"=eltit "gni', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<ciM htiW:ciM tuohtiW ro htiW>"tnetnoc-h"=ssa', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"5.3:)mm ni( retemaiD kcaJ"=eltit "gnidda', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<raeY 1:doireP ytnarraW>"tnetnoc-h"=ssalc nap', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"emoH:egasU"=eltit "gniddap-teser 8-sx-lo', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<emoH:egasU>"tnetnoc-h"=ssalc naps< >naps/<>"', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>")AGXW( 867x6631:noituloseR"=eltit "gnidd', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<)AGXW( 867x6631:noituloseR>"tnetnoc-h"=ssalc', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"2:)zHG ni( deepS kcolC esaB"=eltit "gnid', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], ['"=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<2:)zHG ni( deepS kcolC esaB>"tnetnoc-h"=ssal', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>"oN:draobyeK tilkcaB"=eltit "gniddap-tese', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], ['>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], [' "=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<mm 0021 :eziS naF/peewS>"tnetnoc-h"=ssalc n', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>" sedalB 3 :sedalB fo .oN "=eltit "gnidda', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], [' "=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<sedalB 3 :sedalB fo .oN>"tnetnoc-h"=ssalc n', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>" sttaW 56 :rewoP "=eltit "gniddap-teser ', '>"tnetnoc-h"=ssalc naps< >naps/<>naps/<>"elcric-tsil"=ssalc naps<>"tnoc-elrcic-tsil"=ssalc naps< >"i'], [' "=eltit "gniddap-teser 8-sx-loc"=ssalc il< >il/< >naps/<sttaW 56 :rewoP>"tnetnoc-h"=ssalc naps< >na', '>"tnetnoc-h"=ssalc naps< >naps/<>"elcric-tsil"=ssalc naps<>" 512 :yrevileD riA "=eltit "gniddap-tese', '> ...
# Results are ['i"> <span class="list-cicrle-cont"><span class="list-circle"></span></span> <span class="h-content">']
# Called with
# ['"><span class="list-circle"></span> <span class="h-content">Type:In Ear</span> </li> <li class="col-', '</span> </li> <li class="col-xs-8 reset-padding" title="Wired or Wireless:Wired"><span class="list-c', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# ---------
# ['"><span class="list-circle"></span> <span class="h-content">Wired or Wireless:Wired</span> </li> <li', '</span> </li> <li class="col-xs-8 reset-padding" title="With or Without Mic:With Mic"><span class="l', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['"><span class="list-circle"></span> <span class="h-content">'])
# Called with
# ['"><span class="list-circle"></span> <span class="h-content">Type:In Ear</span> </li> <li class="col-', '</span> </li> <li class="col-xs-8 reset-padding" title="Wired or Wireless:Wired"><span class="list-c', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# ---------
# ['"><span class="list-circle"></span> <span class="h-content">Wired or Wireless:Wired</span> </li> <li', '</span> </li> <li class="col-xs-8 reset-padding" title="With or Without Mic:With Mic"><span class="l', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['"><span class="list-circle"></span> <span class="h-content">', '</span> </li> <li class="col-xs-8 reset-padding" title="Wi'])
# Called with
# ['"><span class="list-circle"></span> <span class="h-content">Type:In Ear</span> </li> <li class="col-', '</span> </li> <li class="col-xs-8 reset-padding" title="Wired or Wireless:Wired"><span class="list-c', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# ---------
# ['"><span class="list-circle"></span> <span class="h-content">Wired or Wireless:Wired</span> </li> <li', '</span> </li> <li class="col-xs-8 reset-padding" title="With or Without Mic:With Mic"><span class="l', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['"><span class="list-circle"></span> <span class="h-content">', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"', '</span> </li> <li class="col-xs-8 reset-padding" title="Wi'])
# Called with
# set(['"><span class="list-circle"></span> <span class="h-content">', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"', '</span> </li> <li class="col-xs-8 reset-padding" title="Wi'])
# ---------
# ['"><span class="list-circle"></span> <span class="h-content">With or Without Mic:With Mic</span> </li', '</span> </li> <li class="col-xs-8 reset-padding" title="Jack Diameter (in mm):3.5"><span class="list', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['"><span class="list-circle"></span> <span class="h-content">'])
# Called with
# set(['"><span class="list-circle"></span> <span class="h-content">', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"', '</span> </li> <li class="col-xs-8 reset-padding" title="Wi'])
# ---------
# ['"><span class="list-circle"></span> <span class="h-content">With or Without Mic:With Mic</span> </li', '</span> </li> <li class="col-xs-8 reset-padding" title="Jack Diameter (in mm):3.5"><span class="list', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['"><span class="list-circle"></span> <span class="h-content">', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"'])
# Called with
# set(['"><span class="list-circle"></span> <span class="h-content">', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"', '</span> </li> <li class="col-xs-8 reset-padding" title="Wi'])
# ---------
# ['"><span class="list-circle"></span> <span class="h-content">With or Without Mic:With Mic</span> </li', '</span> </li> <li class="col-xs-8 reset-padding" title="Jack Diameter (in mm):3.5"><span class="list', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['"><span class="list-circle"></span> <span class="h-content">', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"', '</span> </li> <li class="col-xs-8 reset-padding" title="'])
# Called with
# set(['"><span class="list-circle"></span> <span class="h-content">', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"', '</span> </li> <li class="col-xs-8 reset-padding" title="'])
# ---------
# ['"><span class="list-circle"></span> <span class="h-content">Jack Diameter (in mm):3.5</span> </li> <', '</span> </li> <li class="col-xs-8 reset-padding" title="View all item details"><span class="list-cir', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['"><span class="list-circle"></span> <span class="h-content">'])
# Called with
# set(['"><span class="list-circle"></span> <span class="h-content">', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"', '</span> </li> <li class="col-xs-8 reset-padding" title="'])
# ---------
# ['"><span class="list-circle"></span> <span class="h-content">Jack Diameter (in mm):3.5</span> </li> <', '</span> </li> <li class="col-xs-8 reset-padding" title="View all item details"><span class="list-cir', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['"><span class="list-circle"></span> <span class="h-content">', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"'])
# Called with
# set(['"><span class="list-circle"></span> <span class="h-content">', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"', '</span> </li> <li class="col-xs-8 reset-padding" title="'])
# ---------
# ['"><span class="list-circle"></span> <span class="h-content">Jack Diameter (in mm):3.5</span> </li> <', '</span> </li> <li class="col-xs-8 reset-padding" title="View all item details"><span class="list-cir', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['"><span class="list-circle"></span> <span class="h-content">', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"', '</span> </li> <li class="col-xs-8 reset-padding" title="'])
# Called with
# set(['"><span class="list-circle"></span> <span class="h-content">', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"', '</span> </li> <li class="col-xs-8 reset-padding" title="'])
# ---------
# ['</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set([])
# Called with
# set(['"><span class="list-circle"></span> <span class="h-content">', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"', '</span> </li> <li class="col-xs-8 reset-padding" title="'])
# ---------
# ['</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"'])
# Called with
# set(['"><span class="list-circle"></span> <span class="h-content">', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"', '</span> </li> <li class="col-xs-8 reset-padding" title="'])
# ---------
# ['</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"'])
# ---------
# ['</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"'])
# ---------
# ['</span> </li> <li class="col-xs-8 dtls-li" id="highlightSupc"> <span class="list-cicrle-cont"><span ']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['"><span class="list-circle"></span> <span class="h-content">Usage:Home</span> </li> <li class="col-x', '</span> </li> <li class="col-xs-8 reset-padding" title="Resolution:1366x768 (WXGA)"><span class="lis', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['"><span class="list-circle"></span> <span class="h-content">Resolution:1366x768 (WXGA)</span> </li> ', '</span> </li> <li class="col-xs-8 reset-padding" title="Base Clock Speed (in GHz):2"><span class="li', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['"><span class="list-circle"></span> <span class="h-content">Base Clock Speed (in GHz):2</span> </li>', '</span> </li> <li class="col-xs-8 reset-padding" title="Backlit Keyboard:No"><span class="list-circl', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['"><span class="list-circle"></span> <span class="h-content">Backlit Keyboard:No</span> </li> <li cla', '</span> </li> <li class="col-xs-8 reset-padding" title="View all item details"><span class="list-cir', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['</span> </li> <li class="col-xs-8 dtls-li" id="highlightSupc"> <span class="list-cicrle-cont"><span ']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# [' "><span class="list-circle"></span> <span class="h-content">No. of Blades: 3 Blades</span> </li> <l', '</span> </li> <li class="col-xs-8 reset-padding" title=" Power: 65 Watts "><span class="list-circle"', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# [' "><span class="list-circle"></span> <span class="h-content">Power: 65 Watts</span> </li> <li class=', '</span> </li> <li class="col-xs-8 reset-padding" title=" Air Delivery: 215 "><span class="list-circl', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# [' "><span class="list-circle"></span> <span class="h-content">Air Delivery: 215</span> </li> <li clas', '</span> </li> <li class="col-xs-8 reset-padding" title=" Speed: 380 RPM "><span class="list-circle">', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# [' "><span class="list-circle"></span> <span class="h-content">Speed: 380 RPM</span> </li> <li class="', '</span> </li> <li class="col-xs-8 reset-padding" title="View all item details"><span class="list-cir', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['</span> </li> <li class="col-xs-8 dtls-li" id="highlightSupc"> <span class="list-cicrle-cont"><span ']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['"><span class="list-circle"></span> <span class="h-content">Usage:Home</span> </li> <li class="col-x', '</span> </li> <li class="col-xs-8 reset-padding" title="Resolution:1366x768 (WXGA)"><span class="lis', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['"><span class="list-circle"></span> <span class="h-content">Resolution:1366x768 (WXGA)</span> </li> ', '</span> </li> <li class="col-xs-8 reset-padding" title="Base Clock Speed (in GHz):1.8"><span class="', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['"><span class="list-circle"></span> <span class="h-content">Base Clock Speed (in GHz):1.8</span> </l', '</span> </li> <li class="col-xs-8 reset-padding" title="Backlit Keyboard:No"><span class="list-circl', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['"><span class="list-circle"></span> <span class="h-content">Backlit Keyboard:No</span> </li> <li cla', '</span> </li> <li class="col-xs-8 reset-padding" title="View all item details"><span class="list-cir', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['</span> </li> <li class="col-xs-8 dtls-li" id="highlightSupc"> <span class="list-cicrle-cont"><span ']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['"><span class="list-circle"></span> <span class="h-content">Color:Multi Color</span> </li> <li class', '</span> </li> <li class="col-xs-8 reset-padding" title="Type:Round neck"><span class="list-circle"><', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['"><span class="list-circle"></span> <span class="h-content">Type:Round neck</span> </li> <li class="', '</span> </li> <li class="col-xs-8 reset-padding" title="Fabric:100% Cotton"><span class="list-circle', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['"><span class="list-circle"></span> <span class="h-content">Fabric:100% Cotton</span> </li> <li clas', '</span> </li> <li class="col-xs-8 reset-padding" title="Sleeves:Half Sleeves"><span class="list-circ', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['"><span class="list-circle"></span> <span class="h-content">Sleeves:Half Sleeves</span> </li> <li cl', '</span> </li> <li class="col-xs-8 reset-padding" title="View all item details"><span class="list-cir', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['</span> </li> <li class="col-xs-8 dtls-li" id="highlightSupc"> <span class="list-cicrle-cont"><span ']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['"><span class="list-circle"></span> <span class="h-content">Model No:(USA) Elegance Talking with Ada', '</span> </li> <li class="col-xs-8 reset-padding" title="LCD Display:Yes"><span class="list-circle"><', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['"><span class="list-circle"></span> <span class="h-content">LCD Display:Yes</span> </li> <li class="', '</span> </li> <li class="col-xs-8 reset-padding" title="Power Supply:Both"><span class="list-circle"', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['"><span class="list-circle"></span> <span class="h-content">Power Supply:Both</span> </li> <li class', '</span> </li> <li class="col-xs-8 reset-padding" title="Warranty:1 Year"><span class="list-circle"><', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['"><span class="list-circle"></span> <span class="h-content">Warranty:1 Year</span> </li> <li class="', '</span> </li> <li class="col-xs-8 reset-padding" title="View all item details"><span class="list-cir', '</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['</span> </li> <li class="col-xs-8 dtls-li"> <span class="list-cicrle-cont"><span class="list-circle"']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# Called with
# set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ---------
# ['</span> </li> <li class="col-xs-8 dtls-li" id="highlightSupc"> <span class="list-cicrle-cont"><span ']
# Returning common prefix for set(['</span> </li> <li class="col-xs-8 dtls-li"'])
# ([('i"> <span class="list-cicrle-cont"><span class="list-circle"></span></span> <span class="h-content">',
#    '</span> </li> <li class="col-xs-8 dtls-li"')],
#  0,
#  0,
#  4)

# %%
def getPatternStore(eCommerceDataSetLocation):
    allWebsites = getAllDirectoriesInLocation(eCommerceDataSetLocation)
#     print("All websites are " + str(allWebsites))
    patternsStore = []
    for website in allWebsites:
        corpusLocation = website + "/corpus"
        websiteName = os.path.basename(website)
        (plainPatterns, plainMissed, plainJunkCount, plainTotal) = getAllPatternsByPlainStringMatch(corpusLocation)
        (noValPatterns, noValMissed, noValJunkCount, noValTotal) = getAllPatternsByRetainingOnlyClassValue(corpusLocation)
        if plainMissed < noValMissed:
            patterns = (websiteName, "plainPattern", plainPatterns, plainMissed, plainJunkCount, plainTotal)
#             print(plainPatterns)
        else:
            patterns = (websiteName, "noValuePattern", noValPatterns, noValMissed, noValJunkCount, noValTotal)
        patternsStore.append(patterns)
#     for p in patternsStore:
#         print(p)
    return patternsStore

# %%
def getAllPatternsByRetainingOnlyClassValue(corpusLocation):
    directories             = getAllDirectoriesInLocation(corpusLocation)
    (trainDirs, testDirs)   = trainTestSplit(directories)
    pageLocationsAndSeed    = getPageLocationAndSeed(trainDirs)
    testPageLocationAndSeed = getPageLocationAndSeed(testDirs)
#     print("\n===========================\n")
#     for (a, b) in testPageLocationAndSeed:
#         print("Page location is " + str(a))
#         print("Seeds are " + str(b))
#     print("\n==========================\n")
    leftContexts  = []
    rightContexts = []
    for (pageLocation, seed) in pageLocationsAndSeed:
#         print("pageLocation is " + pageLocation)
#         print("seed is ")
#         print(seed)
        pageContent = doProcessingWithoutClass(preprocessDocument(readPage(pageLocation)))
        (leftContextsPerPage, rightContextsPerPage) = getContextsForAllSeeds(pageContent, seed)
#         (leftContextsPerPage, rightContextsPerPage) = getLeftAndRightContexts(pageContent, seed)
        leftContexts.extend(leftContextsPerPage)
        rightContexts.extend(rightContextsPerPage)
#     printContextInformation(leftContexts, pageLocationsAndSeed, True)
#     printContextInformation(rightContexts, pageLocationsAndSeed)
    leftPatterns = getLeftPatterns(leftContexts)
    rightPatterns = getRightPatterns(rightContexts)
    
#     print("Left patterns are " + str(leftPatterns))
#     print("Right patterns are " + str(rightPatterns))
    patterns = allPossiblePairs(leftPatterns, rightPatterns)
#     print("All possible patterns: ")
#     print(patterns)
    patterns = filterPatterns(pageLocationsAndSeed, patterns, True)
    #TODO if number of patterns are empty go for empty class thing
#     print("Final Patterns ")
#     print(patterns)
    recall = 0
    extraResults = 0
    for (pageLocation, seed) in testPageLocationAndSeed:
        pageContent = doProcessingWithoutClass(preprocessDocument(readPage(pageLocation)))
        resultsPerPage = preprocessResults(list(extractSet(patterns, pageContent)))
#         resultsPerPage = list(set(resultsPerPage))
        flag=True
#         print("Seed wassss " + str(seed))
#         print("Results per page: " + str(resultsPerPage))
        for s in seed:
            if not s in resultsPerPage:
                print("Page location " + str(pageLocation))
                print("\n\nSeed was " + str(s))
                flag=False
        if flag==True:
            recall+=1
#         if seed in resultsPerPage:
#             recall += 1
        extraElements = len(resultsPerPage) - len(seed)
        if extraElements>1:
            seedsLocation = os.path.dirname(pageLocation) + "/seed"
            allSeeds = readAllSeedsAsSet(seedsLocation)
#             print("============================")
#             print("page is " + str(pageLocation))
#             print("All seeds are")
#             print(allSeeds)
#             print("Results per page are: ")
#             print(resultsPerPage)
#             print("============================")
            totalCount = len(resultsPerPage)
            allSeedsCount = len(list(allSeeds.intersection(set(resultsPerPage))))
            extracount = totalCount - allSeedsCount
            extraResults += extracount
#         print("Results per page " + str(resultsPerPage))
    seedsMissed = len(testPageLocationAndSeed)-recall
#     print("Seeds missed: " + str(seedsMissed))
#     print("Extra junk: "+ str(extraResults))
    return (patterns, seedsMissed, extraResults, len(testDirs))
    
# getAllPatternsByRetainingOnlyClassValue(corpusDirectory)

# %%
def writeListToFile(loc, l):
    with open(loc, 'w') as f:
        for item in l:
            f.write(item+"\n")

            
def escapeAllDoubleQuote(s):
    return re.sub("\"", "\\\"", s)
            
def writeSpecificationPatternsToFile(fileLocation, productPatterns):
    header = "GroupId\tWebsiteName\tPatternType\tMissed\tJunk\tOutof\tLeftPattern\tRightPattern"
    groupId = 1
    output = []
    output.append(header)
    for (website, pType, patterns, missed, junk, total) in productPatterns:
        rowPrefix = str(groupId) + "\t" + website + "\t" + pType
        rowPrefix+="\t" + str(missed) + "\t" + str(junk) + "\t" + str(total)
        for (l, r) in patterns:
            row = rowPrefix + "\t" + l + "\t" + r
            output.append(row)
        groupId+=1
#     print("output is ")
#     for item in output:
#         print(item)
    writeListToFile(fileLocation, output)
    print("Output written at location: " + fileLocation)

# %%
print("Enter e-commerce data location: ")
eCommerceDataLocation = raw_input()
print("Enter outputLocation")
outputLocation = raw_input()
outputLocation+="/specifications.tsv"
print("Patterns will be found at " + str(outputLocation))
patternsStore = getPatternStore(eCommerceDataLocation)
print("Pattern store is ")
print(patternsStore)
writeSpecificationPatternsToFile(outputLocation, patternsStore)
#featureSpecificationData
# Out:
# Enter e-commerce data location:
# featureSpecificationData
# Enter outputLocation
# featureSpecificationData
# Patterns will be found at featureSpecificationData/specifications.tsv
# Page location featureSpecificationData/snapdeal/corpus/page9/page.html
#
#
# Seed was Zippered Compartments:2
# Page location featureSpecificationData/snapdeal/corpus/page9/page.html
#
#
# Seed was Waterproof:Yes
# Page location featureSpecificationData/snapdeal/corpus/page9/page.html
#
#
# Seed was Rain Cover:Yes
# Page location featureSpecificationData/snapdeal/corpus/page9/page.html
#
#
# Seed was Colour:Black
# Page location featureSpecificationData/snapdeal/corpus/page9/page.html
#
#
# Seed was Material:Polyester
# Page location featureSpecificationData/snapdeal/corpus/page9/page.html
#
#
# Seed was Compartments:3
# Page location featureSpecificationData/snapdeal/corpus/page9/page.html
#
#
# Seed was Interior Pockets:3 & More
# Page location featureSpecificationData/snapdeal/corpus/page9/page.html
#
#
# Seed was With Trolley:No
# Page location featureSpecificationData/snapdeal/corpus/page9/page.html
#
#
# Seed was Side Pockets:2
# Page location featureSpecificationData/snapdeal/corpus/page9/page.html
#
#
# Seed was Laptop Size:38.1 cm(15)-40 cm(15.9)
# Page location featureSpecificationData/snapdeal/corpus/page9/page.html
#
#
# Seed was Exterior Pockets:2
# Page location featureSpecificationData/snapdeal/corpus/page9/page.html
#
#
# Seed was Design:Solid
# Page location featureSpecificationData/snapdeal/corpus/page9/page.html
#
#
# Seed was Shoulder Strap:Padded
# Page location featureSpecificationData/snapdeal/corpus/page9/page.html
#
#
# Seed was Compatible for:HP
# Page location featureSpecificationData/snapdeal/corpus/page10/page.html
#
#
# Seed was Screen Size (in cm):12.7 cm (5)
# Page location featureSpecificationData/snapdeal/corpus/page10/page.html
#
#
# Seed was Rear Camera:13 MP
# Page location featureSpecificationData/snapdeal/corpus/page10/page.html
#
#
# Seed was Front Camera:8 MP
# Page location featureSpecificationData/snapdeal/corpus/page10/page.html
#
#
# Seed was Internal Memory:32GB
# Page location featureSpecificationData/snapdeal/corpus/page10/page.html
#
#
# Seed was Battery Capacity (in mAh):3500 mAh
# Page location featureSpecificationData/snapdeal/corpus/page10/page.html
#
#
# Seed was Processor Cores:Quad
# Page location featureSpecificationData/snapdeal/corpus/page2/page.html
#
#
# Seed was Pack Size :50 Strips
# Page location featureSpecificationData/snapdeal/corpus/page2/page.html
#
#
# Seed was Expiry(Month&Year):June'2018
# Page location featureSpecificationData/snapdeal/corpus/page2/page.html
#
#
# Seed was Standard Shelf Life (in months):3
# Page location featureSpecificationData/snapdeal/corpus/page4/page.html
#
#
# Seed was Type:Face Wash
# Page location featureSpecificationData/snapdeal/corpus/page4/page.html
#
#
# Seed was Variant Name:Nose Face Mask Blackhead Remover
# Page location featureSpecificationData/snapdeal/corpus/page4/page.html
#
#
# Seed was Form:Liquid
# Page location featureSpecificationData/snapdeal/corpus/page4/page.html
#
#
# Seed was Ideal For:Men & Women
# Pattern store is
# [('flipkart', 'noValuePattern', [('">', '</li><li class="_2-riNZ"')], 0, 0, 4), ('snapdeal', 'noValuePattern', [], 4, 0, 4), ('amazon', 'noValuePattern', [(' </span></li> <li><span class="a-list-item"> ', ' </span></li> <li><span class="a-list-item"> ')], 0, 0, 4)]
# Output written at location: featureSpecificationData/specifications.tsv

# %%
pageLocationsWithSeed = getPageLocationAndSeed(trainDirs)
print(pageLocationsWithSeed)
testPageLocationWithSeed = getPageLocationAndSeed(testDirs)
print(testPageLocationWithSeed)
