# %%
import os
import re
from os import listdir
from os.path import isfile, join

corpusDirectory = "corpus"
def getAllDirectoriesInLocation(loc):
    listOfSubDir = [loc+"/"+f for f in os.listdir(loc)]
    return listOfSubDir



def getFirstLineInPage(fileLocation):
    with open(fileLocation) as f:
        content = f.readlines()
    content = [x.strip() for x in content] 
    return content[0]






def getPageLocationAndSeed(d):
    output = []
    for pageDir in d:
        pageLocation = pageDir + "/page.html"
        seedLocation = pageDir + "/seed"
        seed = getFirstLineInPage(seedLocation)
        output.append((pageLocation, seed))
    return output
    
        
#find all start, end pairs of particular key
def getAllStartEndPairs(document, key):
    keyLength = len(key)
    return [(i, i+keyLength) for i in range(len(document)) if document.startswith(key, i)]
 
    
#find seeds for one particular seed(at this stage call only getAllStartEndPairs())
def getEachSeedLocationsInPage(htmlPageContent, seed):
    return getAllStartEndPairs(htmlPageContent, seed)

        



    #read the page from pageLocation
def readPage(pageLocation):
    htmlPageContent = ""
    with open(pageLocation, 'r') as myfile:
        htmlPageContent = myfile.read().strip()
    return htmlPageContent



#document processing logic at this stage is about removing multiple whitespaces into single one 
def preprocessDocument(document):
    return ' '.join(document.split())


def getCommonPrefix(s1, s2):
    l = [s1, s2]
    return os.path.commonprefix(l)



def insertCommonPrefix(results, commonPrefix):
    if commonPrefix in results or len(commonPrefix)<=0:
        return results
    r = list(results)
    for item in r:
        if len(item)<len(commonPrefix) and commonPrefix.startswith(item):
            results.remove(item)
    r=list(results)
    for item in r:
        if len(item)>len(commonPrefix) and item.startswith(commonPrefix):
            return results
    results.add(commonPrefix)
    return results

def doPrefixIntersection(list1, list2):
    results = set()
    for item1 in list1:
        commonPrefix = ""
        for item2 in list2:
            c = getCommonPrefix(item1, item2)
            if len(c)>len(commonPrefix):
                commonPrefix = c
        results = insertCommonPrefix(results, commonPrefix)
    return results


def doIntersection(patterns):
    if len(patterns)<=0:
        return patterns
    result = patterns[0]
    for index in range(1, len(patterns)):
        result = doPrefixIntersection(result, patterns[index])
    return result



def getLeftPatterns(leftContexts):
    lp = doIntersection(leftContexts)
    results = []
    for item in lp:
        results.append(item[::-1])
    return results


def getRightPatterns(rightContexts):
    return list(doIntersection(rightContexts))
    
    
    
    
    
def allPossiblePairs(leftPatterns, rightPatterns):
    patterns = []
    for lp in leftPatterns:
        for rp in rightPatterns:
            patterns.append((lp, rp))
    return patterns
            
            
            
            
            
#Pattern is (l, r) and match them to htmlPageContent
def findEntitySetwrtPattern(htmlPageContent, (l, r)):
    #for each start location of pattern find its end
    #for each end page find the pattern right
    #extract everything till that point
    #after extraction move one point above that pattern string
    results = []
    for m in re.finditer(re.escape(l), htmlPageContent):
        start = m.start()
        end = m.end()
        rightPage = htmlPageContent[end:]
        rightLoc  = rightPage.find(r)
        if rightLoc==-1:
            break
        element = rightPage[:rightLoc]
        if len(element)>1 and len(element)<300:
            results.append(element)
    return set(results)



#input: all the pattern found and new html page
#output: extract set of elements from the page that are in our set(whose definition we know)
def extractSet(patterns, htmlPageContent):
    output = []
    for pattern in patterns:
        output.extend(findEntitySetwrtPattern(htmlPageContent, pattern))
    return output


def filterPatterns(pageLocationAndSeeds, patterns):
    seedsSet = set()
    for (pageLoc, s) in pageLocationAndSeeds:
        seedsSet.add(s)
    seeds = list(seedsSet)
    patternSuccess = []
    for index in range(0, len(patterns)):
        patternSuccess.append(0)
    for index in range(0, len(patterns)):
        for (pageLocation, seed) in pageLocationAndSeeds:
            pageContent = preprocessDocument(readPage(pageLocation))
            resultsFound = extractSet([patterns[index]], pageContent)
            if seed in resultsFound:
                patternSuccess[index]+=1
                
    output = []
    for index in range(0, len(patterns)):
        if patternSuccess[index]>0:
            output.append(patterns[index])
    return output



def getLeftAndRightContexts(pageContent, seed):
    b = getEachSeedLocationsInPage(pageContent, seed)
    output = []
    totalLength = len(pageContent)
    leftContexts = []
    rightContexts = []
    for (s, e) in b:
        leftContext = pageContent[max(0, s-100):s]
        leftContext = leftContext[::-1]
        rightContext = pageContent[e:min(totalLength, e+100)]
        leftContexts.append(leftContext)
        rightContexts.append(rightContext)
    return (leftContexts, rightContexts)
    

    
    
def printContextInformation(contexts, pageAndSeed, rev=False):
    
    for index in range(0, len(pageAndSeed)):
        (pageLocation, seed) = pageAndSeed[index]
        pageContent = preprocessDocument(readPage(pageLocation))
        contextPerPage = contexts[index]
        print("For seed " + str(seed))
        print("Context is following: " + pageLocation + " number " + str(contextPerPage))
        for item in contextPerPage:
            if rev==True:
                item = item[::-1]
            print(item)
            print("---------------------")


            
#give it the name of directory and get back list of files present in directory
def getAllFilesInDirectory(directory):
    return [join(directory, f) for f in listdir(directory) if isfile(join(directory, f))]

            
def writeListToFile(loc, l):
    thefile = open(loc, 'w')
    for item in l:
        print>>thefile, item
        
        

#remove elements which were actually tag
def isTag(s):
    if s.find("<")!=-1 and s.find(">")!=-1:
        return True
    return False


#preprocess results before writing it to file
def preprocessResults(output):
    result = []
    for o in output:
        if isTag(o):
            continue
        result.append(o)
    return result
        
def getAllPatterns(corpusLocation):
    directories          = getAllDirectoriesInLocation(corpusLocation)
    pageLocationsAndSeed = getPageLocationAndSeed(directories)
    leftContexts  = []
    rightContexts = []
    for (pageLocation, seed) in pageLocationsAndSeed:
        pageContent = preprocessDocument(readPage(pageLocation))
        (leftContextsPerPage, rightContextsPerPage) = getLeftAndRightContexts(pageContent, seed)
        leftContexts.append(leftContextsPerPage)
        rightContexts.append(rightContextsPerPage)
#     print("co")
#     print("Left contexts are " + str(leftContexts))
#     print("Right contexts are " + str(rightContexts))
    printContextInformation(leftContexts, pageLocationsAndSeed, True)
    printContextInformation(rightContexts, pageLocationsAndSeed)
    leftPatterns = getLeftPatterns(leftContexts)
    rightPatterns = getRightPatterns(rightContexts)
    
    print("Left patterns are " + str(leftPatterns))
    print("Right patterns are " + str(rightPatterns))
    patterns = allPossiblePairs(leftPatterns, rightPatterns)
    print("All possible patterns: ")
    print(patterns)
    patterns = filterPatterns(pageLocationsAndSeed, patterns)
    #TODO if number of patterns are empty go for empty class thing
    print("Final Patterns ")
    print(patterns)
    return patterns

patterns = getAllPatterns(corpusDirectory)
unseenCorpusLocation = "unseenCorpus"
unseenCorpusFiles     = getAllFilesInDirectory(unseenCorpusLocation)
unseenResults = []
for productPage in unseenCorpusFiles:
    pageContent = preprocessDocument(readPage(productPage))
    resultsPerPage = preprocessResults(list(extractSet(patterns, pageContent)))
    unseenResults.extend(resultsPerPage)
unseenResults = list(set(unseenResults))
print("Total number of unseen results: " + str(len(unseenResults)))
writeListToFile("unseenSeeds", unseenResults)
# Out:
# For seed Swipe Elite Pro (32GB, 3GB RAM)
# Context is following: corpus/page1/page.html number ['>eltit< >"on=enohpelet"=tnetnoc "noitceted-tamrof"=eman atem< >"8c187044f3c02b8b"=tnetnoc "yek_y"=em', ' yuB"=tnetnoc "noitpircsed"=eman atem< >"pma/336602612166/bg23-orp-etile-epiws/tcudorp/moc.laedpans.', ' rof enilno pohS .aidnI ni secirp tseb ta enilno senohP eliboM )MAR BG3 ,BG23( orP etilE epiwS yuB"=', ' ,senohP eliboM ,stelbaT ;pma& seliboM"=tnetnoc "sdrowyek"=eman atem< >" .aidnI ssorca snoitpo DoC ;', '"=tnetnoc "eltit:go"=ytreporp "eltit_go"=eman atem< >""=tnetnoc "noitpircsed:go"=ytreporp atem< >"me', '"=tnetnoc "eltit:rettiwt"=eman atem< >"laedpans@"=tnetnoc "etis:rettiwt"=eman atem< >"egami_egral_yr', ' yuB"=tnetnoc "noitpircsed:rettiwt"=eman atem< >" aidnI laedpanS | secirP woL ta enilnO senohP elibo', ' rof enilno pohS .aidnI ni secirp tseb ta enilno senohP eliboM )MAR BG3 ,BG23( orP etilE epiwS yuB"=', '"=eulav "neddih"=epyt tupni<>vid/< >vid/<>vid/< >vid/< >lu/< >"] ,};93#&seirogetaC llA eeS;93#& :;93', '"=eltit "daerb-evitca"=ssalc naps< >"bmurcdaerBreniatnoc"=ssalc vid< >naps/< / >"hsalSb"=ssalc naps<', '>")MAR BG3 ,BG23( orP etilE epiwS"=eltit "daerb-evitca"=ssalc naps< >"bmurcdaerBreniatnoc"=ssalc vid', '"=eltit gmi< >";xp8 :mottob-nigram ;xp37 :htdiw ;evitaler :noitisop ;enon :elyts-tsil ;enon :taolf"=', '"=tla ")MAR BG3 ,BG23( orP etilE epiwS"=eltit gmi< >";xp8 :mottob-nigram ;xp37 :htdiw ;evitaler :noi', '"=eltit gmi< >";xp8 :mottob-nigram ;xp37 :htdiw ;evitaler :noitisop ;enon :elyts-tsil ;enon :taolf"=', '"=tla ")MAR BG3 ,BG23( orP etilE epiwS"=eltit gmi< >";xp8 :mottob-nigram ;xp37 :htdiw ;evitaler :noi', '"=eltit gmi< >";xp8 :mottob-nigram ;xp37 :htdiw ;evitaler :noitisop ;enon :elyts-tsil ;enon :taolf"=', '"=tla ")MAR BG3 ,BG23( orP etilE epiwS"=eltit gmi< >";xp8 :mottob-nigram ;xp37 :htdiw ;evitaler :noi', '"=eltit gmi< >";xp8 :mottob-nigram ;xp37 :htdiw ;evitaler :noitisop ;enon :elyts-tsil ;enon :taolf"=', '"=tla ")MAR BG3 ,BG23( orP etilE epiwS"=eltit gmi< >";xp8 :mottob-nigram ;xp37 :htdiw ;evitaler :noi', '"=eltit gmi< >";xp8 :mottob-nigram ;xp37 :htdiw ;evitaler :noitisop ;enon :elyts-tsil ;enon :taolf"=', '"=tla ")MAR BG3 ,BG23( orP etilE epiwS"=eltit gmi< >";xp8 :mottob-nigram ;xp37 :htdiw ;evitaler :noi', '"=eltit "egami"=porpmeti gmi< >";kcolb :yalpsid ;05 :xedni-z ;xp355 :htdiw ;etulosba :noitisop ;enon', '"=eltit gmi< >";enon :yalpsid ;0 :xedni-z ;xp355 :htdiw ;etulosba :noitisop ;enon :elyts-tsil ;enon ', '"=eltit gmi< >";enon :yalpsid ;0 :xedni-z ;xp355 :htdiw ;etulosba :noitisop ;enon :elyts-tsil ;enon ', '"=eltit gmi< >";enon :yalpsid ;0 :xedni-z ;xp355 :htdiw ;etulosba :noitisop ;enon :elyts-tsil ;enon ', '"=eltit gmi< >";enon :yalpsid ;0 :xedni-z ;xp355 :htdiw ;etulosba :noitisop ;enon :elyts-tsil ;enon ', '"=eltit "eman"=porpmeti 1h< >"22-sx-loc"=ssalc vid< >"wor"=ssalc vid< >"tuoyal renni-retnecpot-cele-', ' >"daeh-i-e-pdp"=ssalc ")MAR BG3 ,BG23( orP etilE epiwS"=eltit "eman"=porpmeti 1h< >"22-sx-loc"=ssal', '>"enon-psid"=ssalc "eman"=porpmeti vid< >"kcotSnI/gro.amehcs//:ptth"=ferh "ytilibaliava"=porpmeti kn', '"=emanp-atad "gpj.1cdfd-1-417174654LDS-BG23-orP-etilE-epiwS/4/i/g/sgmi/moc.ndclds.3n//:sptth"=lrugmi', '"=eltit "daol-yzal gmIelit"=ssalc "gpj.1cdfd-1-417174654LDS-BG23-orP-etilE-epiwS/4/i/g/sgmi/moc.ndcl', '"=tla ")MAR BG3 ,BG23( orP etilE epiwS"=eltit "daol-yzal gmIelit"=ssalc "gpj.1cdfd-1-417174654LDS-BG', '>"eltit-tcudorp"=ssalc p< >"csed-elit"=ssalc vid< >vid/< >")MAR BG3 ,BG23( orP etilE epiwS"=tla ")MA', '" :"PDPemaNtcudorp" ,"571" :"dItac" ,"eurt" :"elbanEstegdiWrelles" ,"eurt" : "evitcAeeCsi" \'woN yuB\'']
# me="y_key" content="b8b20c3f440781c8"> <meta name="format-detection" content="telephone=no"> <title>
# ---------------------
# .snapdeal.com/product/swipe-elite-pro-32gb/661216206633/amp"> <meta name="description" content="Buy
# ---------------------
# ="Buy Swipe Elite Pro (32GB, 3GB RAM) Mobile Phones online at best prices in India. Shop online for
# ---------------------
# ; CoD options across India. "> <meta name="keywords" content="Mobiles &amp; Tablets, Mobile Phones,
# ---------------------
# em"> <meta property="og:description" content=""> <meta name="og_title" property="og:title" content="
# ---------------------
# ry_large_image"> <meta name="twitter:site" content="@snapdeal"> <meta name="twitter:title" content="
# ---------------------
# obile Phones Online at Low Prices | Snapdeal India "> <meta name="twitter:description" content="Buy
# ---------------------
# ="Buy Swipe Elite Pro (32GB, 3GB RAM) Mobile Phones online at best prices in India. Shop online for
# ---------------------
# 39;: &#39;See All Categories&#39;}, ]"> </ul> </div> </div></div> </div><input type="hidden" value="
# ---------------------
# <span class="bSlash"> / </span> <div class="containerBreadcrumb"> <span class="active-bread" title="
# ---------------------
# div class="containerBreadcrumb"> <span class="active-bread" title="Swipe Elite Pro (32GB, 3GB RAM)">
# ---------------------
# ="float: none; list-style: none; position: relative; width: 73px; margin-bottom: 8px;"> <img title="
# ---------------------
# ion: relative; width: 73px; margin-bottom: 8px;"> <img title="Swipe Elite Pro (32GB, 3GB RAM)" alt="
# ---------------------
# ="float: none; list-style: none; position: relative; width: 73px; margin-bottom: 8px;"> <img title="
# ---------------------
# ion: relative; width: 73px; margin-bottom: 8px;"> <img title="Swipe Elite Pro (32GB, 3GB RAM)" alt="
# ---------------------
# ="float: none; list-style: none; position: relative; width: 73px; margin-bottom: 8px;"> <img title="
# ---------------------
# ion: relative; width: 73px; margin-bottom: 8px;"> <img title="Swipe Elite Pro (32GB, 3GB RAM)" alt="
# ---------------------
# ="float: none; list-style: none; position: relative; width: 73px; margin-bottom: 8px;"> <img title="
# ---------------------
# ion: relative; width: 73px; margin-bottom: 8px;"> <img title="Swipe Elite Pro (32GB, 3GB RAM)" alt="
# ---------------------
# ="float: none; list-style: none; position: relative; width: 73px; margin-bottom: 8px;"> <img title="
# ---------------------
# ion: relative; width: 73px; margin-bottom: 8px;"> <img title="Swipe Elite Pro (32GB, 3GB RAM)" alt="
# ---------------------
# none; position: absolute; width: 553px; z-index: 50; display: block;"> <img itemprop="image" title="
# ---------------------
#  none; list-style: none; position: absolute; width: 553px; z-index: 0; display: none;"> <img title="
# ---------------------
#  none; list-style: none; position: absolute; width: 553px; z-index: 0; display: none;"> <img title="
# ---------------------
#  none; list-style: none; position: absolute; width: 553px; z-index: 0; display: none;"> <img title="
# ---------------------
#  none; list-style: none; position: absolute; width: 553px; z-index: 0; display: none;"> <img title="
# ---------------------
# -elec-topcenter-inner layout"> <div class="row"> <div class="col-xs-22"> <h1 itemprop="name" title="
# ---------------------
# lass="col-xs-22"> <h1 itemprop="name" title="Swipe Elite Pro (32GB, 3GB RAM)" class="pdp-e-i-head">
# ---------------------
# nk itemprop="availability" href="http://schema.org/InStock"> <div itemprop="name" class="disp-none">
# ---------------------
# imgurl="https://n3.sdlcdn.com/imgs/g/i/4/Swipe-Elite-Pro-32GB-SDL456471714-1-dfdc1.jpg" data-pname="
# ---------------------
# lcdn.com/imgs/g/i/4/Swipe-Elite-Pro-32GB-SDL456471714-1-dfdc1.jpg" class="tileImg lazy-load" title="
# ---------------------
# GB-SDL456471714-1-dfdc1.jpg" class="tileImg lazy-load" title="Swipe Elite Pro (32GB, 3GB RAM)" alt="
# ---------------------
# AM)" alt="Swipe Elite Pro (32GB, 3GB RAM)"> </div> <div class="tile-desc"> <p class="product-title">
# ---------------------
# 'Buy Now' "isCeeActive" : "true", "sellerWidgetsEnable": "true", "catId": "175", "productNamePDP": "
# ---------------------
# For seed Casio Enticer Analog Grey Dial Men's Watch - Mtp-1374l-7a1vdf(a955)
# Context is following: corpus/page3/page.html number ['>eltit< >"on=enohpelet"=tnetnoc "noitceted-tamrof"=eman atem< >"8c187044f3c02b8b"=tnetnoc "yek_y"=em', ' yuB - )559a(fdv1a7-l4731-ptM - hctaW s\'neM laiD yerG golanA recitnE oisaC>eltit< >"on=enohpelet"=tn', ' >")559a(fdv1a7-l4731-ptM - hctaW s;93#&neM laiD yerG golanA recitnE oisaC "=eltit "daerb-evitca"=ss', ' >"daeh-i-e-pdp"=ssalc ")559a(fdv1a7-l4731-ptM - hctaW s;93#&neM laiD yerG golanA recitnE oisaC"=elt', '>"enon-psid"=ssalc "eman"=porpmeti vid< >"kcotSnI/gro.amehcs//:ptth"=ferh "ytilibaliava"=porpmeti kn', '>"eltit-tcudorp"=ssalc p< >"csed-elit"=ssalc vid< >vid/< >")559a(fdv1a7-l4731-ptM - hctaW s;93#&neM ']
# me="y_key" content="b8b20c3f440781c8"> <meta name="format-detection" content="telephone=no"> <title>
# ---------------------
# nt="telephone=no"> <title>Casio Enticer Analog Grey Dial Men's Watch - Mtp-1374l-7a1vdf(a955) - Buy
# ---------------------
# ss="active-bread" title=" Casio Enticer Analog Grey Dial Men&#39;s Watch - Mtp-1374l-7a1vdf(a955)">
# ---------------------
# tle="Casio Enticer Analog Grey Dial Men&#39;s Watch - Mtp-1374l-7a1vdf(a955)" class="pdp-e-i-head">
# ---------------------
# nk itemprop="availability" href="http://schema.org/InStock"> <div itemprop="name" class="disp-none">
# ---------------------
#  Men&#39;s Watch - Mtp-1374l-7a1vdf(a955)"> </div> <div class="tile-desc"> <p class="product-title">
# ---------------------
# For seed Xolo Era 2 (8GB, 4G)
# Context is following: corpus/page2/page.html number ['>eltit< >"on=enohpelet"=tnetnoc "noitceted-tamrof"=eman atem< >"8c187044f3c02b8b"=tnetnoc "yek_y"=em', ' yuB"=tnetnoc "noitpircsed"=eman atem< >"pma/069681563936/kcalb-bg8-2-are-olox/tcudorp/moc.laedpans.', ' rof enilno pohS .aidnI ni secirp tseb ta enilno senohP eliboM )G4 ,BG8( 2 arE oloX yuB"=tnetnoc "no', ' ,senohP eliboM ,stelbaT ;pma& seliboM"=tnetnoc "sdrowyek"=eman atem< >" .aidnI ssorca snoitpo DoC ;', '"=tnetnoc "eltit:go"=ytreporp "eltit_go"=eman atem< >""=tnetnoc "noitpircsed:go"=ytreporp atem< >"me', '"=tnetnoc "eltit:rettiwt"=eman atem< >"laedpans@"=tnetnoc "etis:rettiwt"=eman atem< >"egami_egral_yr', ' yuB"=tnetnoc "noitpircsed:rettiwt"=eman atem< >" aidnI laedpanS | secirP woL ta enilnO senohP elibo', ' rof enilno pohS .aidnI ni secirp tseb ta enilno senohP eliboM )G4 ,BG8( 2 arE oloX yuB"=tnetnoc "no', '"=eulav "neddih"=epyt tupni<>vid/< >vid/<>vid/< >vid/< >lu/< >"] ,};93#&seirogetaC llA eeS;93#& :;93', '"=eltit "daerb-evitca"=ssalc naps< >"bmurcdaerBreniatnoc"=ssalc vid< >naps/< / >"hsalSb"=ssalc naps<', '>")G4 ,BG8( 2 arE oloX"=eltit "daerb-evitca"=ssalc naps< >"bmurcdaerBreniatnoc"=ssalc vid< >naps/< /', '"=eltit gmi< >";xp8 :mottob-nigram ;xp37 :htdiw ;evitaler :noitisop ;enon :elyts-tsil ;enon :taolf"=', '"=tla ")G4 ,BG8( 2 arE oloX"=eltit gmi< >";xp8 :mottob-nigram ;xp37 :htdiw ;evitaler :noitisop ;enon', '"=eltit gmi< >";xp8 :mottob-nigram ;xp37 :htdiw ;evitaler :noitisop ;enon :elyts-tsil ;enon :taolf"=', '"=tla ")G4 ,BG8( 2 arE oloX"=eltit gmi< >";xp8 :mottob-nigram ;xp37 :htdiw ;evitaler :noitisop ;enon', '"=eltit gmi< >";xp8 :mottob-nigram ;xp37 :htdiw ;evitaler :noitisop ;enon :elyts-tsil ;enon :taolf"=', '"=tla ")G4 ,BG8( 2 arE oloX"=eltit gmi< >";xp8 :mottob-nigram ;xp37 :htdiw ;evitaler :noitisop ;enon', '"=eltit gmi< >";xp8 :mottob-nigram ;xp37 :htdiw ;evitaler :noitisop ;enon :elyts-tsil ;enon :taolf"=', '"=tla ")G4 ,BG8( 2 arE oloX"=eltit gmi< >";xp8 :mottob-nigram ;xp37 :htdiw ;evitaler :noitisop ;enon', '"=eltit "egami"=porpmeti gmi< >";kcolb :yalpsid ;05 :xedni-z ;xp355 :htdiw ;etulosba :noitisop ;enon', '"=eltit gmi< >";enon :yalpsid ;0 :xedni-z ;xp355 :htdiw ;etulosba :noitisop ;enon :elyts-tsil ;enon ', '"=eltit gmi< >";enon :yalpsid ;0 :xedni-z ;xp355 :htdiw ;etulosba :noitisop ;enon :elyts-tsil ;enon ', '"=eltit gmi< >";enon :yalpsid ;0 :xedni-z ;xp355 :htdiw ;etulosba :noitisop ;enon :elyts-tsil ;enon ', '"=eltit "eman"=porpmeti 1h< >"22-sx-loc"=ssalc vid< >"wor"=ssalc vid< >"tuoyal renni-retnecpot-cele-', ' >"daeh-i-e-pdp"=ssalc ")G4 ,BG8( 2 arE oloX"=eltit "eman"=porpmeti 1h< >"22-sx-loc"=ssalc vid< >"wo', '>"enon-psid"=ssalc "eman"=porpmeti vid< >"kcotSnI/gro.amehcs//:ptth"=ferh "ytilibaliava"=porpmeti kn', '"=emanp-atad "gnp.01bdf-3-603109767LDS-dimaryP-BG8-2-arE-oloX/v/j/e/sgmi/moc.ndclds.3n//:sptth"=lrug', '"=eltit "daol-yzal gmIelit"=ssalc "gnp.01bdf-3-603109767LDS-dimaryP-BG8-2-arE-oloX/v/j/e/sgmi/moc.nd', '"=tla ")G4 ,BG8( 2 arE oloX"=eltit "daol-yzal gmIelit"=ssalc "gnp.01bdf-3-603109767LDS-dimaryP-BG8-2', '>"eltit-tcudorp"=ssalc p< >"csed-elit"=ssalc vid< >vid/< >")G4 ,BG8( 2 arE oloX"=tla ")G4 ,BG8( 2 ar', '" :"PDPemaNtcudorp" ,"571" :"dItac" ,"eurt" :"elbanEstegdiWrelles" ,"eurt" : "evitcAeeCsi" \'woN yuB\'']
# me="y_key" content="b8b20c3f440781c8"> <meta name="format-detection" content="telephone=no"> <title>
# ---------------------
# .snapdeal.com/product/xolo-era-2-8gb-black/639365186960/amp"> <meta name="description" content="Buy
# ---------------------
# on" content="Buy Xolo Era 2 (8GB, 4G) Mobile Phones online at best prices in India. Shop online for
# ---------------------
# ; CoD options across India. "> <meta name="keywords" content="Mobiles &amp; Tablets, Mobile Phones,
# ---------------------
# em"> <meta property="og:description" content=""> <meta name="og_title" property="og:title" content="
# ---------------------
# ry_large_image"> <meta name="twitter:site" content="@snapdeal"> <meta name="twitter:title" content="
# ---------------------
# obile Phones Online at Low Prices | Snapdeal India "> <meta name="twitter:description" content="Buy
# ---------------------
# on" content="Buy Xolo Era 2 (8GB, 4G) Mobile Phones online at best prices in India. Shop online for
# ---------------------
# 39;: &#39;See All Categories&#39;}, ]"> </ul> </div> </div></div> </div><input type="hidden" value="
# ---------------------
# <span class="bSlash"> / </span> <div class="containerBreadcrumb"> <span class="active-bread" title="
# ---------------------
# / </span> <div class="containerBreadcrumb"> <span class="active-bread" title="Xolo Era 2 (8GB, 4G)">
# ---------------------
# ="float: none; list-style: none; position: relative; width: 73px; margin-bottom: 8px;"> <img title="
# ---------------------
# none; position: relative; width: 73px; margin-bottom: 8px;"> <img title="Xolo Era 2 (8GB, 4G)" alt="
# ---------------------
# ="float: none; list-style: none; position: relative; width: 73px; margin-bottom: 8px;"> <img title="
# ---------------------
# none; position: relative; width: 73px; margin-bottom: 8px;"> <img title="Xolo Era 2 (8GB, 4G)" alt="
# ---------------------
# ="float: none; list-style: none; position: relative; width: 73px; margin-bottom: 8px;"> <img title="
# ---------------------
# none; position: relative; width: 73px; margin-bottom: 8px;"> <img title="Xolo Era 2 (8GB, 4G)" alt="
# ---------------------
# ="float: none; list-style: none; position: relative; width: 73px; margin-bottom: 8px;"> <img title="
# ---------------------
# none; position: relative; width: 73px; margin-bottom: 8px;"> <img title="Xolo Era 2 (8GB, 4G)" alt="
# ---------------------
# none; position: absolute; width: 553px; z-index: 50; display: block;"> <img itemprop="image" title="
# ---------------------
#  none; list-style: none; position: absolute; width: 553px; z-index: 0; display: none;"> <img title="
# ---------------------
#  none; list-style: none; position: absolute; width: 553px; z-index: 0; display: none;"> <img title="
# ---------------------
#  none; list-style: none; position: absolute; width: 553px; z-index: 0; display: none;"> <img title="
# ---------------------
# -elec-topcenter-inner layout"> <div class="row"> <div class="col-xs-22"> <h1 itemprop="name" title="
# ---------------------
# ow"> <div class="col-xs-22"> <h1 itemprop="name" title="Xolo Era 2 (8GB, 4G)" class="pdp-e-i-head">
# ---------------------
# nk itemprop="availability" href="http://schema.org/InStock"> <div itemprop="name" class="disp-none">
# ---------------------
# gurl="https://n3.sdlcdn.com/imgs/e/j/v/Xolo-Era-2-8GB-Pyramid-SDL767901306-3-fdb10.png" data-pname="
# ---------------------
# dn.com/imgs/e/j/v/Xolo-Era-2-8GB-Pyramid-SDL767901306-3-fdb10.png" class="tileImg lazy-load" title="
# ---------------------
# 2-8GB-Pyramid-SDL767901306-3-fdb10.png" class="tileImg lazy-load" title="Xolo Era 2 (8GB, 4G)" alt="
# ---------------------
# ra 2 (8GB, 4G)" alt="Xolo Era 2 (8GB, 4G)"> </div> <div class="tile-desc"> <p class="product-title">
# ---------------------
# 'Buy Now' "isCeeActive" : "true", "sellerWidgetsEnable": "true", "catId": "175", "productNamePDP": "
# ---------------------
# For seed Indian Polity Paperback English
# Context is following: corpus/page4/page.html number ['>eltit< >"on=enohpelet"=tnetnoc "noitceted-tamrof"=eman atem< >"8c187044f3c02b8b"=tnetnoc "yek_y"=em', ' yuB :hsilgnE kcabrepaP ytiloP naidnI>eltit< >"on=enohpelet"=tnetnoc "noitceted-tamrof"=eman atem< >', ' yuB"=tnetnoc "noitpircsed"=eman atem< >"pma/262644621336/hsilgne-kcabrepap-ytilop-naidni/tcudorp/mo', ' daeR .laedpanS no aidnI ni ecirp tseb ta enilno hsilgnE kcabrepaP ytiloP naidnI yuB"=tnetnoc "noitp', '"=tnetnoc "sdrowyek"=eman atem< >" .aidnI ssorca snoitpo DoC ;pma& gnippihs eerF teG .sliated rohtua', '"=tnetnoc "eltit:go"=ytreporp "eltit_go"=eman atem< >""=tnetnoc "noitpircsed:go"=ytreporp atem< >"me', '"=tnetnoc "eltit:rettiwt"=eman atem< >"laedpans@"=tnetnoc "etis:rettiwt"=eman atem< >"egami_egral_yr', ' yuB :hsilgnE kcabrepaP ytiloP naidnI"=tnetnoc "eltit:rettiwt"=eman atem< >"laedpans@"=tnetnoc "etis', ' yuB"=tnetnoc "noitpircsed:rettiwt"=eman atem< >" laedpanS no aidnI ni ecirP woL ta enilnO hsilgnE k', ' daeR .laedpanS no aidnI ni ecirp tseb ta enilno hsilgnE kcabrepaP ytiloP naidnI yuB"=tnetnoc "noitp', '"=eulav "neddih"=epyt tupni<>vid/< >vid/<>vid/< >vid/< >lu/< >"] ,};93#&seirogetaC llA eeS;93#& :;93', ' "=eltit "daerb-evitca"=ssalc naps< >"bmurcdaerBreniatnoc"=ssalc vid< >i/<>"txen-noci-ds noci-ds"=ss', ' >"hsilgnE kcabrepaP ytiloP naidnI "=eltit "daerb-evitca"=ssalc naps< >"bmurcdaerBreniatnoc"=ssalc v', '"=eltit "egami"=porpmeti gmi< >";kcolb :yalpsid ;05 :xedni-z ;xp236 :htdiw ;etulosba :noitisop ;enon', '"=eltit "eman"=porpmeti 1h< >"22-sx-loc"=ssalc vid< >"wor"=ssalc vid< >"tuoyal renni-retnecpot-cele-', ' >"daeh-i-e-pdp"=ssalc "hsilgnE kcabrepaP ytiloP naidnI"=eltit "eman"=porpmeti 1h< >"22-sx-loc"=ssal', '>"enon-psid"=ssalc "eman"=porpmeti vid< >"kcotSnI/gro.amehcs//:ptth"=ferh "ytilibaliava"=porpmeti kn', '"=eltit "daol-yzal gmIelit"=ssalc "gpj.0fb67-1-287534698LDS-hsilgnE-kcabrepaP-ytiloP-naidnI/7/6/c/sg', '"=tla "hsilgnE kcabrepaP ytiloP naidnI"=eltit "daol-yzal gmIelit"=ssalc "gpj.0fb67-1-287534698LDS-hs', '>"eltit-tcudorp"=ssalc p< >"csed-elit"=ssalc vid< >vid/< >"hsilgnE kcabrepaP ytiloP naidnI"=tla "hsi', '" :"PDPemaNtcudorp" ,"573" :"dItac" ,"eurt" :"elbanEstegdiWrelles" ,"eurt" : "evitcAeeCsi" \'woN yuB\'']
# me="y_key" content="b8b20c3f440781c8"> <meta name="format-detection" content="telephone=no"> <title>
# ---------------------
# > <meta name="format-detection" content="telephone=no"> <title>Indian Polity Paperback English: Buy
# ---------------------
# om/product/indian-polity-paperback-english/633126446262/amp"> <meta name="description" content="Buy
# ---------------------
# ption" content="Buy Indian Polity Paperback English online at best price in India on Snapdeal. Read
# ---------------------
# author details. Get Free shipping &amp; CoD options across India. "> <meta name="keywords" content="
# ---------------------
# em"> <meta property="og:description" content=""> <meta name="og_title" property="og:title" content="
# ---------------------
# ry_large_image"> <meta name="twitter:site" content="@snapdeal"> <meta name="twitter:title" content="
# ---------------------
# site" content="@snapdeal"> <meta name="twitter:title" content="Indian Polity Paperback English: Buy
# ---------------------
# k English Online at Low Price in India on Snapdeal "> <meta name="twitter:description" content="Buy
# ---------------------
# ption" content="Buy Indian Polity Paperback English online at best price in India on Snapdeal. Read
# ---------------------
# 39;: &#39;See All Categories&#39;}, ]"> </ul> </div> </div></div> </div><input type="hidden" value="
# ---------------------
# ss="sd-icon sd-icon-next"></i> <div class="containerBreadcrumb"> <span class="active-bread" title="
# ---------------------
# v class="containerBreadcrumb"> <span class="active-bread" title=" Indian Polity Paperback English">
# ---------------------
# none; position: absolute; width: 632px; z-index: 50; display: block;"> <img itemprop="image" title="
# ---------------------
# -elec-topcenter-inner layout"> <div class="row"> <div class="col-xs-22"> <h1 itemprop="name" title="
# ---------------------
# lass="col-xs-22"> <h1 itemprop="name" title="Indian Polity Paperback English" class="pdp-e-i-head">
# ---------------------
# nk itemprop="availability" href="http://schema.org/InStock"> <div itemprop="name" class="disp-none">
# ---------------------
# gs/c/6/7/Indian-Polity-Paperback-English-SDL896435782-1-76bf0.jpg" class="tileImg lazy-load" title="
# ---------------------
# sh-SDL896435782-1-76bf0.jpg" class="tileImg lazy-load" title="Indian Polity Paperback English" alt="
# ---------------------
# ish" alt="Indian Polity Paperback English"> </div> <div class="tile-desc"> <p class="product-title">
# ---------------------
# 'Buy Now' "isCeeActive" : "true", "sellerWidgetsEnable": "true", "catId": "375", "productNamePDP": "
# ---------------------
# For seed Swipe Elite Pro (32GB, 3GB RAM)
# Context is following: corpus/page1/page.html number [' Mobile Phones Online at Low Prices | Snapdeal India </title> <link rel="canonical" href="https://ww', ' Mobile Phones online at best prices in India. Shop online for Swipe Elite Pro (32GB, 3GB RAM) only ', ' only on Snapdeal. Get Free Shipping &amp; CoD options across India. "> <meta name="keywords" conten', ', Snapdeal, India, price, discount, offer "> <meta name="robots" content="index, follow "> <meta nam', '"> <meta name="og_site_name" property="og:site_name" content="Snapdeal.com"> <meta name="og_image" p', ' Mobile Phones Online at Low Prices | Snapdeal India "> <meta name="twitter:description" content="Bu', ' Mobile Phones online at best prices in India. Shop online for Swipe Elite Pro (32GB, 3GB RAM) only ', ' only on Snapdeal. Get Free Shipping &amp; CoD options across India. "> <meta name="twitter:image:sr', '" id="productNamePDP"> <input type="hidden" id="superCategoryLabel" name="superCategoryLabel" value=', '">Swipe Elite Pro (32GB, 3GB RAM)</span> </div> </div> <div class="clear"></div> </div> <script type', '</span> </div> </div> <div class="clear"></div> </div> <script type="text/jqtmpl" id="breadCrumbDrop', '" alt="Swipe Elite Pro (32GB, 3GB RAM)" src="./page_files/Swipe-Elite-Pro-32GB-SDL456471714-1-dfdc1.', '" src="./page_files/Swipe-Elite-Pro-32GB-SDL456471714-1-dfdc1.jpg"> </a> <a data-slide-index="1" hre', '" alt="Swipe Elite Pro (32GB, 3GB RAM)" src="./page_files/Swipe-Elite-Pro-32GB-SDL456471714-2-0cfab.', '" src="./page_files/Swipe-Elite-Pro-32GB-SDL456471714-2-0cfab.png"> </a> <a data-slide-index="2" hre', '" alt="Swipe Elite Pro (32GB, 3GB RAM)" src="./page_files/Swipe-Elite-Pro-32GB-SDL456471714-3-059a8.', '" src="./page_files/Swipe-Elite-Pro-32GB-SDL456471714-3-059a8.jpg"> </a> <a data-slide-index="3" hre', '" alt="Swipe Elite Pro (32GB, 3GB RAM)" src="./page_files/Swipe-Elite-Pro-32GB-SDL456471714-4-c51f3.', '" src="./page_files/Swipe-Elite-Pro-32GB-SDL456471714-4-c51f3.jpg"> </a> <a data-slide-index="4" hre', '" alt="Swipe Elite Pro (32GB, 3GB RAM)" src="./page_files/Swipe-Elite-Pro-32GB-SDL456471714-5-52215.', '" src="./page_files/Swipe-Elite-Pro-32GB-SDL456471714-5-52215.jpg"> </a> </div></div><div class="bx-', '" slidenum="0" class="cloudzoom" bigsrc="https://n3.sdlcdn.com/imgs/g/i/4/Swipe-Elite-Pro-32GB-SDL45', '" slidenum="1" class="cloudzoom" bigsrc="https://n4.sdlcdn.com/imgs/g/i/4/Swipe-Elite-Pro-32GB-SDL45', '" slidenum="2" class="cloudzoom" bigsrc="https://n2.sdlcdn.com/imgs/g/i/4/Swipe-Elite-Pro-32GB-SDL45', '" slidenum="3" class="cloudzoom" bigsrc="https://n2.sdlcdn.com/imgs/g/i/4/Swipe-Elite-Pro-32GB-SDL45', '" slidenum="4" class="cloudzoom" bigsrc="https://n2.sdlcdn.com/imgs/g/i/4/Swipe-Elite-Pro-32GB-SDL45', '" class="pdp-e-i-head"> Swipe Elite Pro (32GB, 3GB RAM)</h1> </div> <div class="col-xs-2"> <div clas', '</h1> </div> <div class="col-xs-2"> <div class="shortlist-icon-wrpr comp-animated-icon "> <span clas', '</div> <div id="buyPriceBox" class="elecPriceTile buyNowBlock row"> <div class="col-xs-21 reset-padd', '"> <span class="icon-wrapr"> <i class="sd-icon sd-icon-compare-new"></i> </span> <span class="animat', '" alt="Swipe Elite Pro (32GB, 3GB RAM)"> </div> <div class="tile-desc"> <p class="product-title">Swi', '"> </div> <div class="tile-desc"> <p class="product-title">Swipe Elite Pro (32GB, 3GB RAM)</p> <p cl', '</p> <p class="product-offer-price"> Rs. 6,999</p> <div class="product-cut-price">Rs. 8,199</div> </', '", "hardBundlingCss": "https://i1.sdlcdn.com/css/amex1507014675285/snap/components/bundling/hardBund']
#  Mobile Phones Online at Low Prices | Snapdeal India </title> <link rel="canonical" href="https://ww
# ---------------------
#  Mobile Phones online at best prices in India. Shop online for Swipe Elite Pro (32GB, 3GB RAM) only
# ---------------------
#  only on Snapdeal. Get Free Shipping &amp; CoD options across India. "> <meta name="keywords" conten
# ---------------------
# , Snapdeal, India, price, discount, offer "> <meta name="robots" content="index, follow "> <meta nam
# ---------------------
# "> <meta name="og_site_name" property="og:site_name" content="Snapdeal.com"> <meta name="og_image" p
# ---------------------
#  Mobile Phones Online at Low Prices | Snapdeal India "> <meta name="twitter:description" content="Bu
# ---------------------
#  Mobile Phones online at best prices in India. Shop online for Swipe Elite Pro (32GB, 3GB RAM) only
# ---------------------
#  only on Snapdeal. Get Free Shipping &amp; CoD options across India. "> <meta name="twitter:image:sr
# ---------------------
# " id="productNamePDP"> <input type="hidden" id="superCategoryLabel" name="superCategoryLabel" value=
# ---------------------
# ">Swipe Elite Pro (32GB, 3GB RAM)</span> </div> </div> <div class="clear"></div> </div> <script type
# ---------------------
# </span> </div> </div> <div class="clear"></div> </div> <script type="text/jqtmpl" id="breadCrumbDrop
# ---------------------
# " alt="Swipe Elite Pro (32GB, 3GB RAM)" src="./page_files/Swipe-Elite-Pro-32GB-SDL456471714-1-dfdc1.
# ---------------------
# " src="./page_files/Swipe-Elite-Pro-32GB-SDL456471714-1-dfdc1.jpg"> </a> <a data-slide-index="1" hre
# ---------------------
# " alt="Swipe Elite Pro (32GB, 3GB RAM)" src="./page_files/Swipe-Elite-Pro-32GB-SDL456471714-2-0cfab.
# ---------------------
# " src="./page_files/Swipe-Elite-Pro-32GB-SDL456471714-2-0cfab.png"> </a> <a data-slide-index="2" hre
# ---------------------
# " alt="Swipe Elite Pro (32GB, 3GB RAM)" src="./page_files/Swipe-Elite-Pro-32GB-SDL456471714-3-059a8.
# ---------------------
# " src="./page_files/Swipe-Elite-Pro-32GB-SDL456471714-3-059a8.jpg"> </a> <a data-slide-index="3" hre
# ---------------------
# " alt="Swipe Elite Pro (32GB, 3GB RAM)" src="./page_files/Swipe-Elite-Pro-32GB-SDL456471714-4-c51f3.
# ---------------------
# " src="./page_files/Swipe-Elite-Pro-32GB-SDL456471714-4-c51f3.jpg"> </a> <a data-slide-index="4" hre
# ---------------------
# " alt="Swipe Elite Pro (32GB, 3GB RAM)" src="./page_files/Swipe-Elite-Pro-32GB-SDL456471714-5-52215.
# ---------------------
# " src="./page_files/Swipe-Elite-Pro-32GB-SDL456471714-5-52215.jpg"> </a> </div></div><div class="bx-
# ---------------------
# " slidenum="0" class="cloudzoom" bigsrc="https://n3.sdlcdn.com/imgs/g/i/4/Swipe-Elite-Pro-32GB-SDL45
# ---------------------
# " slidenum="1" class="cloudzoom" bigsrc="https://n4.sdlcdn.com/imgs/g/i/4/Swipe-Elite-Pro-32GB-SDL45
# ---------------------
# " slidenum="2" class="cloudzoom" bigsrc="https://n2.sdlcdn.com/imgs/g/i/4/Swipe-Elite-Pro-32GB-SDL45
# ---------------------
# " slidenum="3" class="cloudzoom" bigsrc="https://n2.sdlcdn.com/imgs/g/i/4/Swipe-Elite-Pro-32GB-SDL45
# ---------------------
# " slidenum="4" class="cloudzoom" bigsrc="https://n2.sdlcdn.com/imgs/g/i/4/Swipe-Elite-Pro-32GB-SDL45
# ---------------------
# " class="pdp-e-i-head"> Swipe Elite Pro (32GB, 3GB RAM)</h1> </div> <div class="col-xs-2"> <div clas
# ---------------------
# </h1> </div> <div class="col-xs-2"> <div class="shortlist-icon-wrpr comp-animated-icon "> <span clas
# ---------------------
# </div> <div id="buyPriceBox" class="elecPriceTile buyNowBlock row"> <div class="col-xs-21 reset-padd
# ---------------------
# "> <span class="icon-wrapr"> <i class="sd-icon sd-icon-compare-new"></i> </span> <span class="animat
# ---------------------
# " alt="Swipe Elite Pro (32GB, 3GB RAM)"> </div> <div class="tile-desc"> <p class="product-title">Swi
# ---------------------
# "> </div> <div class="tile-desc"> <p class="product-title">Swipe Elite Pro (32GB, 3GB RAM)</p> <p cl
# ---------------------
# </p> <p class="product-offer-price"> Rs. 6,999</p> <div class="product-cut-price">Rs. 8,199</div> </
# ---------------------
# ", "hardBundlingCss": "https://i1.sdlcdn.com/css/amex1507014675285/snap/components/bundling/hardBund
# ---------------------
# For seed Casio Enticer Analog Grey Dial Men's Watch - Mtp-1374l-7a1vdf(a955)
# Context is following: corpus/page3/page.html number [" - Buy Casio Enticer Analog Grey Dial Men's Watch - Mtp-1374l-7a1vdf(a955) Online at Best Prices in ", ' Online at Best Prices in India on Snapdeal </title> <link rel="canonical" href="https://www.snapdea', '</span> </div></div> <div class="clear"></div> </div> <script type="text/jqtmpl" id="breadCrumbDropd', '</h1> </div> <div class="col-xs-2"> <div class="shortlist-icon-wrpr comp-animated-icon "> <span clas', '</div> <div id="buyPriceBox" class="elecPriceTile buyNowBlock row"> <div class="col-xs-21 reset-padd', '</p> <p class="product-offer-price"> Rs. 3,929</p> <div class="product-cut-price">Rs. 4,295</div> </']
#  - Buy Casio Enticer Analog Grey Dial Men's Watch - Mtp-1374l-7a1vdf(a955) Online at Best Prices in
# ---------------------
#  Online at Best Prices in India on Snapdeal </title> <link rel="canonical" href="https://www.snapdea
# ---------------------
# </span> </div></div> <div class="clear"></div> </div> <script type="text/jqtmpl" id="breadCrumbDropd
# ---------------------
# </h1> </div> <div class="col-xs-2"> <div class="shortlist-icon-wrpr comp-animated-icon "> <span clas
# ---------------------
# </div> <div id="buyPriceBox" class="elecPriceTile buyNowBlock row"> <div class="col-xs-21 reset-padd
# ---------------------
# </p> <p class="product-offer-price"> Rs. 3,929</p> <div class="product-cut-price">Rs. 4,295</div> </
# ---------------------
# For seed Xolo Era 2 (8GB, 4G)
# Context is following: corpus/page2/page.html number [' Mobile Phones Online at Low Prices | Snapdeal India </title> <link rel="canonical" href="https://ww', ' Mobile Phones online at best prices in India. Shop online for Xolo Era 2 (8GB, 4G) only on Snapdeal', ' only on Snapdeal. Get Free Shipping &amp; CoD options across India. "> <meta name="keywords" conten', ', Snapdeal, India, price, discount, offer "> <meta name="robots" content="index, follow "> <meta nam', '"> <meta name="og_site_name" property="og:site_name" content="Snapdeal.com"> <meta name="og_image" p', ' Mobile Phones Online at Low Prices | Snapdeal India "> <meta name="twitter:description" content="Bu', ' Mobile Phones online at best prices in India. Shop online for Xolo Era 2 (8GB, 4G) only on Snapdeal', ' only on Snapdeal. Get Free Shipping &amp; CoD options across India. "> <meta name="twitter:image:sr', '" id="productNamePDP"> <input type="hidden" id="superCategoryLabel" name="superCategoryLabel" value=', '">Xolo Era 2 (8GB, 4G)</span> </div> </div> <div class="clear"></div> </div> <script type="text/jqtm', '</span> </div> </div> <div class="clear"></div> </div> <script type="text/jqtmpl" id="breadCrumbDrop', '" alt="Xolo Era 2 (8GB, 4G)" src="./page2_files/Xolo-Era-2-8GB-Pyramid-SDL767901306-3-fdb10.png"> </', '" src="./page2_files/Xolo-Era-2-8GB-Pyramid-SDL767901306-3-fdb10.png"> </a> <a data-slide-index="1" ', '" alt="Xolo Era 2 (8GB, 4G)" src="./page2_files/Xolo-Era-2-8GB-Pyramid-SDL767901306-1-d3c55.png"> </', '" src="./page2_files/Xolo-Era-2-8GB-Pyramid-SDL767901306-1-d3c55.png"> </a> <a data-slide-index="2" ', '" alt="Xolo Era 2 (8GB, 4G)" src="./page2_files/Xolo-Era-2-8GB-Pyramid-SDL767901306-2-6950f.png"> </', '" src="./page2_files/Xolo-Era-2-8GB-Pyramid-SDL767901306-2-6950f.png"> </a> <a data-slide-index="3" ', '" alt="Xolo Era 2 (8GB, 4G)" src="./page2_files/Xolo-Era-2-8GB-Pyramid-SDL767901306-4-a5275.png"> </', '" src="./page2_files/Xolo-Era-2-8GB-Pyramid-SDL767901306-4-a5275.png"> </a> </div></div><div class="', '" slidenum="0" class="cloudzoom" bigsrc="https://n3.sdlcdn.com/imgs/e/j/v/Xolo-Era-2-8GB-Pyramid-SDL', '" slidenum="1" class="cloudzoom" bigsrc="https://n4.sdlcdn.com/imgs/e/j/v/Xolo-Era-2-8GB-Pyramid-SDL', '" slidenum="2" class="cloudzoom" bigsrc="https://n3.sdlcdn.com/imgs/e/j/v/Xolo-Era-2-8GB-Pyramid-SDL', '" slidenum="3" class="cloudzoom" bigsrc="https://n1.sdlcdn.com/imgs/e/j/v/Xolo-Era-2-8GB-Pyramid-SDL', '" class="pdp-e-i-head"> Xolo Era 2 (8GB, 4G)</h1> </div> <div class="col-xs-2"> <div class="shortlis', '</h1> </div> <div class="col-xs-2"> <div class="shortlist-icon-wrpr comp-animated-icon "> <span clas', '</div> <div id="buyPriceBox" class="elecPriceTile buyNowBlock row"> <div class="col-xs-21 reset-padd', '"> <span class="icon-wrapr"> <i class="sd-icon sd-icon-compare-new"></i> </span> <span class="animat', '" alt="Xolo Era 2 (8GB, 4G)"> </div> <div class="tile-desc"> <p class="product-title">Xolo Era 2 (8G', '"> </div> <div class="tile-desc"> <p class="product-title">Xolo Era 2 (8GB, 4G)</p> <p class="produc', '</p> <p class="product-offer-price"> Rs. 4,199</p> <div class="product-cut-price">Rs. 5,299</div> </', '", "hardBundlingCss": "https://i1.sdlcdn.com/css/amex1507014675285/snap/components/bundling/hardBund']
#  Mobile Phones Online at Low Prices | Snapdeal India </title> <link rel="canonical" href="https://ww
# ---------------------
#  Mobile Phones online at best prices in India. Shop online for Xolo Era 2 (8GB, 4G) only on Snapdeal
# ---------------------
#  only on Snapdeal. Get Free Shipping &amp; CoD options across India. "> <meta name="keywords" conten
# ---------------------
# , Snapdeal, India, price, discount, offer "> <meta name="robots" content="index, follow "> <meta nam
# ---------------------
# "> <meta name="og_site_name" property="og:site_name" content="Snapdeal.com"> <meta name="og_image" p
# ---------------------
#  Mobile Phones Online at Low Prices | Snapdeal India "> <meta name="twitter:description" content="Bu
# ---------------------
#  Mobile Phones online at best prices in India. Shop online for Xolo Era 2 (8GB, 4G) only on Snapdeal
# ---------------------
#  only on Snapdeal. Get Free Shipping &amp; CoD options across India. "> <meta name="twitter:image:sr
# ---------------------
# " id="productNamePDP"> <input type="hidden" id="superCategoryLabel" name="superCategoryLabel" value=
# ---------------------
# ">Xolo Era 2 (8GB, 4G)</span> </div> </div> <div class="clear"></div> </div> <script type="text/jqtm
# ---------------------
# </span> </div> </div> <div class="clear"></div> </div> <script type="text/jqtmpl" id="breadCrumbDrop
# ---------------------
# " alt="Xolo Era 2 (8GB, 4G)" src="./page2_files/Xolo-Era-2-8GB-Pyramid-SDL767901306-3-fdb10.png"> </
# ---------------------
# " src="./page2_files/Xolo-Era-2-8GB-Pyramid-SDL767901306-3-fdb10.png"> </a> <a data-slide-index="1"
# ---------------------
# " alt="Xolo Era 2 (8GB, 4G)" src="./page2_files/Xolo-Era-2-8GB-Pyramid-SDL767901306-1-d3c55.png"> </
# ---------------------
# " src="./page2_files/Xolo-Era-2-8GB-Pyramid-SDL767901306-1-d3c55.png"> </a> <a data-slide-index="2"
# ---------------------
# " alt="Xolo Era 2 (8GB, 4G)" src="./page2_files/Xolo-Era-2-8GB-Pyramid-SDL767901306-2-6950f.png"> </
# ---------------------
# " src="./page2_files/Xolo-Era-2-8GB-Pyramid-SDL767901306-2-6950f.png"> </a> <a data-slide-index="3"
# ---------------------
# " alt="Xolo Era 2 (8GB, 4G)" src="./page2_files/Xolo-Era-2-8GB-Pyramid-SDL767901306-4-a5275.png"> </
# ---------------------
# " src="./page2_files/Xolo-Era-2-8GB-Pyramid-SDL767901306-4-a5275.png"> </a> </div></div><div class="
# ---------------------
# " slidenum="0" class="cloudzoom" bigsrc="https://n3.sdlcdn.com/imgs/e/j/v/Xolo-Era-2-8GB-Pyramid-SDL
# ---------------------
# " slidenum="1" class="cloudzoom" bigsrc="https://n4.sdlcdn.com/imgs/e/j/v/Xolo-Era-2-8GB-Pyramid-SDL
# ---------------------
# " slidenum="2" class="cloudzoom" bigsrc="https://n3.sdlcdn.com/imgs/e/j/v/Xolo-Era-2-8GB-Pyramid-SDL
# ---------------------
# " slidenum="3" class="cloudzoom" bigsrc="https://n1.sdlcdn.com/imgs/e/j/v/Xolo-Era-2-8GB-Pyramid-SDL
# ---------------------
# " class="pdp-e-i-head"> Xolo Era 2 (8GB, 4G)</h1> </div> <div class="col-xs-2"> <div class="shortlis
# ---------------------
# </h1> </div> <div class="col-xs-2"> <div class="shortlist-icon-wrpr comp-animated-icon "> <span clas
# ---------------------
# </div> <div id="buyPriceBox" class="elecPriceTile buyNowBlock row"> <div class="col-xs-21 reset-padd
# ---------------------
# "> <span class="icon-wrapr"> <i class="sd-icon sd-icon-compare-new"></i> </span> <span class="animat
# ---------------------
# " alt="Xolo Era 2 (8GB, 4G)"> </div> <div class="tile-desc"> <p class="product-title">Xolo Era 2 (8G
# ---------------------
# "> </div> <div class="tile-desc"> <p class="product-title">Xolo Era 2 (8GB, 4G)</p> <p class="produc
# ---------------------
# </p> <p class="product-offer-price"> Rs. 4,199</p> <div class="product-cut-price">Rs. 5,299</div> </
# ---------------------
# ", "hardBundlingCss": "https://i1.sdlcdn.com/css/amex1507014675285/snap/components/bundling/hardBund
# ---------------------
# For seed Indian Polity Paperback English
# Context is following: corpus/page4/page.html number [': Buy Indian Polity Paperback English Online at Low Price in India on Snapdeal </title> <link rel="c', ' Online at Low Price in India on Snapdeal </title> <link rel="canonical" href="https://www.snapdeal.', ' online at best price in India on Snapdeal. Read Indian Polity Paperback English reviews &amp; autho', ' reviews &amp; author details. Get Free shipping &amp; CoD options across India. "> <meta name="keyw', ', Civil Services Exams, Competitive Exams, Prices, Shopping, Shop, Online, Discount, India, Snapdeal', '"> <meta name="og_site_name" property="og:site_name" content="Snapdeal.com"> <meta name="og_image" p', ': Buy Indian Polity Paperback English Online at Low Price in India on Snapdeal "> <meta name="twitte', ' Online at Low Price in India on Snapdeal "> <meta name="twitter:description" content="Buy Indian Po', ' online at best price in India on Snapdeal. Read Indian Polity Paperback English reviews &amp; autho', ' reviews &amp; author details. Get Free shipping &amp; CoD options across India. "> <meta name="twit', '" id="productNamePDP"> <input type="hidden" id="superCategoryLabel" name="superCategoryLabel" value=', '"> Indian Polity Paperback English</span> </div></div> <div class="clear"></div> </div> <script type', '</span> </div></div> <div class="clear"></div> </div> <script type="text/jqtmpl" id="breadCrumbDropd', '" slidenum="0" class="cloudzoom" bigsrc="https://n2.sdlcdn.com/imgs/c/6/7/Indian-Polity-Paperback-En', '" class="pdp-e-i-head"> Indian Polity Paperback English</h1> </div> <div class="col-xs-2"> <div clas', '</h1> </div> <div class="col-xs-2"> <div class="shortlist-icon-wrpr comp-animated-icon "> <span clas', '</div> <div id="buyPriceBox" class="elecPriceTile buyNowBlock row"> <div class="col-xs-21 reset-padd', '" alt="Indian Polity Paperback English"> </div> <div class="tile-desc"> <p class="product-title">Ind', '"> </div> <div class="tile-desc"> <p class="product-title">Indian Polity Paperback English</p> <p cl', '</p> <p class="product-offer-price"> Rs. 540</p> <div class="product-cut-price">Rs. 710</div> </div>', '", "hardBundlingCss": "https://i1.sdlcdn.com/css/amex1507014675285/snap/components/bundling/hardBund']
# : Buy Indian Polity Paperback English Online at Low Price in India on Snapdeal </title> <link rel="c
# ---------------------
#  Online at Low Price in India on Snapdeal </title> <link rel="canonical" href="https://www.snapdeal.
# ---------------------
#  online at best price in India on Snapdeal. Read Indian Polity Paperback English reviews &amp; autho
# ---------------------
#  reviews &amp; author details. Get Free shipping &amp; CoD options across India. "> <meta name="keyw
# ---------------------
# , Civil Services Exams, Competitive Exams, Prices, Shopping, Shop, Online, Discount, India, Snapdeal
# ---------------------
# "> <meta name="og_site_name" property="og:site_name" content="Snapdeal.com"> <meta name="og_image" p
# ---------------------
# : Buy Indian Polity Paperback English Online at Low Price in India on Snapdeal "> <meta name="twitte
# ---------------------
#  Online at Low Price in India on Snapdeal "> <meta name="twitter:description" content="Buy Indian Po
# ---------------------
#  online at best price in India on Snapdeal. Read Indian Polity Paperback English reviews &amp; autho
# ---------------------
#  reviews &amp; author details. Get Free shipping &amp; CoD options across India. "> <meta name="twit
# ---------------------
# " id="productNamePDP"> <input type="hidden" id="superCategoryLabel" name="superCategoryLabel" value=
# ---------------------
# "> Indian Polity Paperback English</span> </div></div> <div class="clear"></div> </div> <script type
# ---------------------
# </span> </div></div> <div class="clear"></div> </div> <script type="text/jqtmpl" id="breadCrumbDropd
# ---------------------
# " slidenum="0" class="cloudzoom" bigsrc="https://n2.sdlcdn.com/imgs/c/6/7/Indian-Polity-Paperback-En
# ---------------------
# " class="pdp-e-i-head"> Indian Polity Paperback English</h1> </div> <div class="col-xs-2"> <div clas
# ---------------------
# </h1> </div> <div class="col-xs-2"> <div class="shortlist-icon-wrpr comp-animated-icon "> <span clas
# ---------------------
# </div> <div id="buyPriceBox" class="elecPriceTile buyNowBlock row"> <div class="col-xs-21 reset-padd
# ---------------------
# " alt="Indian Polity Paperback English"> </div> <div class="tile-desc"> <p class="product-title">Ind
# ---------------------
# "> </div> <div class="tile-desc"> <p class="product-title">Indian Polity Paperback English</p> <p cl
# ---------------------
# </p> <p class="product-offer-price"> Rs. 540</p> <div class="product-cut-price">Rs. 710</div> </div>
# ---------------------
# ", "hardBundlingCss": "https://i1.sdlcdn.com/css/amex1507014675285/snap/components/bundling/hardBund
# ---------------------
# Left patterns are ['"> </div> <div class="tile-desc"> <p class="product-title">', 'me="y_key" content="b8b20c3f440781c8"> <meta name="format-detection" content="telephone=no"> <title>', 'Buy ', '" class="pdp-e-i-head"> ', 'nk itemprop="availability" href="http://schema.org/InStock"> <div itemprop="name" class="disp-none">']
# Right patterns are ['</div> <div id="buyPriceBox" class="elecPriceTile buyNowBlock row"> <div class="col-xs-21 reset-padd', ' ', '</p> <p class="product-offer-price"> Rs. ', '</h1> </div> <div class="col-xs-2"> <div class="shortlist-icon-wrpr comp-animated-icon "> <span clas', '</span> </div>']
# All possible patterns:
# [('"> </div> <div class="tile-desc"> <p class="product-title">', '</div> <div id="buyPriceBox" class="elecPriceTile buyNowBlock row"> <div class="col-xs-21 reset-padd'), ('"> </div> <div class="tile-desc"> <p class="product-title">', ' '), ('"> </div> <div class="tile-desc"> <p class="product-title">', '</p> <p class="product-offer-price"> Rs. '), ('"> </div> <div class="tile-desc"> <p class="product-title">', '</h1> </div> <div class="col-xs-2"> <div class="shortlist-icon-wrpr comp-animated-icon "> <span clas'), ('"> </div> <div class="tile-desc"> <p class="product-title">', '</span> </div>'), ('me="y_key" content="b8b20c3f440781c8"> <meta name="format-detection" content="telephone=no"> <title>', '</div> <div id="buyPriceBox" class="elecPriceTile buyNowBlock row"> <div class="col-xs-21 reset-padd'), ('me="y_key" content="b8b20c3f440781c8"> <meta name="format-detection" content="telephone=no"> <title>', ' '), ('me="y_key" content="b8b20c3f440781c8"> <meta name="format-detection" content="telephone=no"> <title>', '</p> <p class="product-offer-price"> Rs. '), ('me="y_key" content="b8b20c3f440781c8"> <meta name="format-detection" content="telephone=no"> <title>', '</h1> </div> <div class="col-xs-2"> <div class="shortlist-icon-wrpr comp-animated-icon "> <span clas'), ('me="y_key" content="b8b20c3f440781c8"> <meta name="format-detection" content="telephone=no"> <title>', '</span> </div>'), ('Buy ', '</div> <div id="buyPriceBox" class="elecPriceTile buyNowBlock row"> <div class="col-xs-21 reset-padd'), ('Buy ', ' '), ('Buy ', '</p> <p class="product-offer-price"> Rs. '), ('Buy ', '</h1> </div> <div class="col-xs-2"> <div class="shortlist-icon-wrpr comp-animated-icon "> <span clas'), ('Buy ', '</span> </div>'), ('" class="pdp-e-i-head"> ', '</div> <div id="buyPriceBox" class="elecPriceTile buyNowBlock row"> <div class="col-xs-21 reset-padd'), ('" class="pdp-e-i-head"> ', ' '), ('" class="pdp-e-i-head"> ', '</p> <p class="product-offer-price"> Rs. '), ('" class="pdp-e-i-head"> ', '</h1> </div> <div class="col-xs-2"> <div class="shortlist-icon-wrpr comp-animated-icon "> <span clas'), ('" class="pdp-e-i-head"> ', '</span> </div>'), ('nk itemprop="availability" href="http://schema.org/InStock"> <div itemprop="name" class="disp-none">', '</div> <div id="buyPriceBox" class="elecPriceTile buyNowBlock row"> <div class="col-xs-21 reset-padd'), ('nk itemprop="availability" href="http://schema.org/InStock"> <div itemprop="name" class="disp-none">', ' '), ('nk itemprop="availability" href="http://schema.org/InStock"> <div itemprop="name" class="disp-none">', '</p> <p class="product-offer-price"> Rs. '), ('nk itemprop="availability" href="http://schema.org/InStock"> <div itemprop="name" class="disp-none">', '</h1> </div> <div class="col-xs-2"> <div class="shortlist-icon-wrpr comp-animated-icon "> <span clas'), ('nk itemprop="availability" href="http://schema.org/InStock"> <div itemprop="name" class="disp-none">', '</span> </div>')]
# Final Patterns
# [('"> </div> <div class="tile-desc"> <p class="product-title">', '</p> <p class="product-offer-price"> Rs. '), ('" class="pdp-e-i-head"> ', '</h1> </div> <div class="col-xs-2"> <div class="shortlist-icon-wrpr comp-animated-icon "> <span clas'), ('nk itemprop="availability" href="http://schema.org/InStock"> <div itemprop="name" class="disp-none">', '</div> <div id="buyPriceBox" class="elecPriceTile buyNowBlock row"> <div class="col-xs-21 reset-padd')]
# Total number of unseen results: 108

# %%
def getHtmlStart():
    header = "<html><head></head><body>"
    return header
def getHtmlEnd():
    footer = "</body></head>"
def getHtmlSection(title, items):
    items = list(items)
    output = "<h4>" + title +"</h4></br><ul>"
    
    for item in items:
        output+="<li>"+item+</li>+"</br>"
    output+="</ul></br></hr>"
